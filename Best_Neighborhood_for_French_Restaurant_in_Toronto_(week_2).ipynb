# %% [markdown]
# <a href="https://colab.research.google.com/github/BobbyRex/IBM-Capstone-Battle-of-the-neighborhoods/blob/Final/Best_Neighborhood_for_French_Restaurant_in_Toronto_(week_2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Using Foursquare data and neighbourhood profiles to find the best spot in Toronto to start up a French restaurant
#
# ##*Background*
# According to the last census, more than 50,000 Torontonians identified themselves as francophones. Every year roughly 1,000 French-speaking immigrants settle in Toronto, with the occasional spike – after the 2011 earthquake in Haiti, for example [1](https://www.theglobeandmail.com/news/toronto/a-cultural-shift-for-toronto-as-invisible-francophones-settle-in/article26232519/). There is, however, no defined francophone neighborhood in Toronto. For those who wish to start up a French restaurant, this project aims to select the best neighborhood in Toronto for this matter. Variables taken into account includes e.g. french speaking rate, average income, crime rate, migration rate, restaurant frequency.
#
# ##*Material and methods*
# Datasets on  [Toronto neighborhood profiles](https://open.toronto.ca/dataset/neighbourhood-profiles/) and crime statistics from the [Toronto Police Service](https://data.torontopolice.on.ca/pages/asr-open-data) will be merged. Restaurants, grouped by neighborhood, will be obtained through requests from the Foursquare API. A score will be calculated based on selected variables predicted to influence the decision. Top scoring neighborhoods will be suberimposed over a map of Toronto using Folium. The relative contribution of each selected variable to the final score will be calculated and plotted. Scores will subsequently be compared between groups generated by *k*-means clustering. The provided material will serve as basis for further exploration of the neighborhoods by the customer wishing to start up a French restaurant in Toronto.

# %% [markdown]
# ####First, lets import the required libraries:

# %%
# %matplotlib inline 
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json
from geopy.geocoders import Nominatim
import requests
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import folium
import io
from bs4 import BeautifulSoup
print('Libraries imported.')
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer
from sklearn import preprocessing
from sklearn.metrics import r2_score
# Out:
# Libraries imported.

# %% [markdown]
# ####Variables needed later to access Geopy and Foursquare API

# %%
#Foursquare
CLIENT_ID = 'BJYOEN12FKXPVNXL53N3E0IYSTUKWRXIN0KWV5L5HUQOTV2C' 
CLIENT_SECRET = 'AW2MRYSVU3O2FBZRMUSZ3LBMKZK5K0REYASL5BDSF15DYBGY' 
VERSION = '20180604'
LIMIT = 300 

#Getting coordinates of Toronto
address = 'Toronto, ON'
geolocator = Nominatim(user_agent="on_explorer")
location = geolocator.geocode(address, timeout=15)
latitude = location.latitude
longitude = location.longitude

# %% [markdown]
# ####Let's define the functions needed later on

# %%
def get_toronto_data():
#To import downloaded dataset on Toronto census from https://ckan0.cf.opendata.inter.prod-toronto.ca/download_resource/ef0239b1-832b-4d0b-a1f3-4153e53b189e?format=csv 
  from google.colab import files
  uploaded = files.upload()
  demographics = pd.read_csv(io.BytesIO(uploaded['neighbourhood-profiles-2016-csv.csv']), thousands=',')
  return demographics

def get_crime_rates():
# to fetch crime data from the Toronto Police and calculate a total crime rate per neighborhood  
  # !wget -q -O 'crimes.json' "https://services.arcgis.com/S9th0jAJ7bqgIRjw/arcgis/rest/services/Neighbourhood_MCI/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json"
  
  with open('crimes.json') as json_data:
    crime_data = json.load(json_data)
  
  features = crime_data['features']
  
  column_names = ['Neighborhood', "Assault rate", "Autotheft rate", "Breakandenter rate", "Homicide rate", "Robbery rate", "Theftover rate"] 
  crimes = pd.DataFrame(columns=column_names)

  for data in features:
    neigh = data['attributes']['Neighbourhood'] 
    assault = data['attributes']['Assault_Rate_2019']
    auto = data['attributes']['AutoTheft_Rate_2019']
    bae = data['attributes']['BreakandEnter_Rate_2019']
    homicide = data['attributes']['Homicide_Rate_2019']
    robbery = data['attributes']['Robbery_Rate_2019']
    theft = data['attributes']['TheftOver_Rate_2019']
    crimes = crimes.append({'Neighborhood': neigh,
                                          'Assault rate': assault,
                                          'Autotheft rate': auto,
                                          'Breakandenter rate': bae,
                                          'Homicide rate': homicide,
                                          'Robbery rate': robbery,
                                          'Theftover rate': theft}, ignore_index=True)

  crimes['Total crime rate'] = crimes.sum(axis=1)
  return(crimes)


def getNearbyVenues(names, latitudes, longitudes, radius=1000):
#fix to only fetch restaurants?   
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['id'],
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue',
                  'id', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# ###1. Construct a demographics dataframe
# ####I will use the neighbourhood profiles 2016 dataset from the [Toronto open data portal](https://ckan0.cf.opendata.inter.prod-toronto.ca/download_resource/ef0239b1-832b-4d0b-a1f3-4153e53b189e?format=csv):

# %%
to_data = get_toronto_data() 
to_data.head()
# Out:
#      <input type="file" id="files-ceba61aa-9b25-4667-8914-fee62f4f49ea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ceba61aa-9b25-4667-8914-fee62f4f49ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving neighbourhood-profiles-2016-csv.csv to neighbourhood-profiles-2016-csv.csv
#    _id                   Category                      Topic  \
# 0    1  Neighbourhood Information  Neighbourhood Information
# 1    2  Neighbourhood Information  Neighbourhood Information
# 2    3                 Population   Population and dwellings
# 3    4                 Population   Population and dwellings
# 4    5                 Population   Population and dwellings
#
#                       Data Source               Characteristic  \
# 0                 City of Toronto         Neighbourhood Number
# 1                 City of Toronto         TSNS2020 Designation
# 2  Census Profile 98-316-X2016001             Population, 2016
# 3  Census Profile 98-316-X2016001             Population, 2011
# 4  Census Profile 98-316-X2016001  Population Change 2011-2016
#
#   City of Toronto Agincourt North Agincourt South-Malvern West  \
# 0             NaN             129                          128
# 1             NaN  No Designation               No Designation
# 2       2,731,571          29,113                       23,757
# 3       2,615,060          30,279                       21,988
# 4           4.50%          -3.90%                        8.00%
#
#         Alderwood           Annex Banbury-Don Mills  Bathurst Manor  \
# 0              20              95                42              34
# 1  No Designation  No Designation    No Designation  No Designation
# 2          12,054          30,526            27,695          15,873
# 3          11,904          29,177            26,918          15,434
# 4           1.30%           4.60%             2.90%           2.80%
#
#   Bay Street Corridor Bayview Village Bayview Woods-Steeles  \
# 0                  76              52                    49
# 1      No Designation  No Designation        No Designation
# 2              25,797          21,396                13,154
# 3              19,348          17,671                13,530
# 4              33.30%          21.10%                -2.80%
#
#   Bedford Park-Nortown Beechborough-Greenbrook         Bendale  \
# 0                   39                     112             127
# 1       No Designation                     NIA  No Designation
# 2               23,236                   6,577          29,960
# 3               23,185                   6,488          27,876
# 4                0.20%                   1.40%           7.50%
#
#   Birchcliffe-Cliffside Black Creek     Blake-Jones Briar Hill-Belgravia  \
# 0                   122          24              69                  108
# 1        No Designation         NIA  No Designation       No Designation
# 2                22,291      21,737           7,727               14,257
# 3                21,856      22,057           7,763               14,302
# 4                 2.00%      -1.50%          -0.50%               -0.30%
#
#   Bridle Path-Sunnybrook-York Mills Broadview North Brookhaven-Amesbury  \
# 0                                41              57                  30
# 1                    No Designation  No Designation      No Designation
# 2                             9,266          11,499              17,757
# 3                             8,713          11,563              17,787
# 4                             6.30%          -0.60%              -0.20%
#
#   Cabbagetown-South St. James Town Caledonia-Fairbank       Casa Loma  \
# 0                               71                109              96
# 1                   No Designation     No Designation  No Designation
# 2                           11,669              9,955          10,968
# 3                           12,053              9,851          10,487
# 4                           -3.20%              1.10%           4.60%
#
#   Centennial Scarborough Church-Yonge Corridor Clairlea-Birchmount  \
# 0                    133                    75                 120
# 1         No Designation        No Designation      No Designation
# 2                 13,362                31,340              26,984
# 3                 13,093                28,349              24,770
# 4                  2.10%                10.60%               8.90%
#
#      Clanton Park      Cliffcrest Corso Italia-Davenport        Danforth  \
# 0              33             123                     92              66
# 1  No Designation  No Designation         No Designation  No Designation
# 2          16,472          15,935                 14,133           9,666
# 3          14,612          15,703                 13,743           9,444
# 4          12.70%           1.50%                  2.80%           2.40%
#
#   Danforth East York Don Valley Village             Dorset Park  \
# 0                 59                 47                     126
# 1     No Designation     No Designation  Emerging Neighbourhood
# 2             17,180             27,051                  25,003
# 3             16,712             26,739                  24,363
# 4              2.80%              1.20%                   2.60%
#
#   Dovercourt-Wallace Emerson-Junction Downsview-Roding-CFB  Dufferin Grove  \
# 0                                  93                   26              83
# 1                      No Designation                  NIA  No Designation
# 2                              36,625               35,052          11,785
# 3                              34,631               34,659          11,449
# 4                               5.80%                1.10%           2.90%
#
#   East End-Danforth Edenbridge-Humber Valley Eglinton East Elms-Old Rexdale  \
# 0                62                        9           138                5
# 1    No Designation           No Designation           NIA              NIA
# 2            21,381                   15,535        22,776            9,456
# 3            20,839                   14,943        22,829            9,550
# 4             2.60%                    4.00%        -0.20%           -1.00%
#
#       Englemount-Lawrence Eringate-Centennial-West Deane Etobicoke West Mall  \
# 0                      32                             11                  13
# 1  Emerging Neighbourhood                 No Designation      No Designation
# 2                  22,372                         18,588              11,848
# 3                  22,086                         18,810              10,927
# 4                   1.30%                         -1.20%               8.40%
#
#   Flemingdon Park Forest Hill North Forest Hill South Glenfield-Jane Heights  \
# 0              44               102               101                     25
# 1             NIA    No Designation    No Designation                    NIA
# 2          21,933            12,806            10,732                 30,491
# 3          22,168            12,474            10,926                 31,390
# 4          -1.10%             2.70%            -1.80%                 -2.90%
#
#   Greenwood-Coxwell       Guildwood      Henry Farm High Park North  \
# 0                65             140              53              88
# 1    No Designation  No Designation  No Designation  No Designation
# 2            14,417           9,917          15,723          22,162
# 3            14,083           9,816          11,333          21,292
# 4             2.40%           1.00%          38.70%           4.10%
#
#   High Park-Swansea  Highland Creek Hillcrest Village  \
# 0                87             134                48
# 1    No Designation  No Designation    No Designation
# 2            23,925          12,494            16,934
# 3            21,740          13,097            17,656
# 4            10.10%          -4.60%            -4.10%
#
#   Humber Heights-Westmount Humber Summit Humbermede Humewood-Cedarvale  \
# 0                        8            21         22                106
# 1   Emerging Neighbourhood           NIA        NIA     No Designation
# 2                   10,948        12,416     15,545             14,365
# 3                   10,583        12,525     15,853             14,108
# 4                    3.40%        -0.90%     -1.90%              1.80%
#
#   Ionview Islington-City Centre West   Junction Area Keelesdale-Eglinton West  \
# 0     125                         14              90                      110
# 1     NIA             No Designation  No Designation                      NIA
# 2  13,641                     43,965          14,366                   11,058
# 3  13,091                     38,084          14,027                   10,638
# 4   4.20%                     15.40%           2.40%                    3.90%
#
#   Kennedy Park Kensington-Chinatown Kingsview Village-The Westway  \
# 0          124                   78                             6
# 1          NIA       No Designation                           NIA
# 2       17,123               17,945                        22,000
# 3       17,058               18,495                        21,723
# 4        0.40%               -3.00%                         1.30%
#
#    Kingsway South Lambton Baby Point              L'Amoreaux Lansing-Westgate  \
# 0              15                114                     117               38
# 1  No Designation     No Designation  Emerging Neighbourhood   No Designation
# 2           9,271              7,985                  43,993           16,164
# 3           9,170              7,921                  44,919           14,642
# 4           1.10%              0.80%                  -2.10%           10.40%
#
#   Lawrence Park North Lawrence Park South Leaside-Bennington Little Portugal  \
# 0                 105                 103                 56              84
# 1      No Designation      No Designation     No Designation  No Designation
# 2              14,607              15,179             16,828          15,559
# 3              14,541              15,070             17,011          12,050
# 4               0.50%               0.70%             -1.10%          29.10%
#
#       Long Branch                 Malvern      Maple Leaf   Markland Wood  \
# 0              19                     132              29              12
# 1  No Designation  Emerging Neighbourhood  No Designation  No Designation
# 2          10,084                  43,794          10,111          10,554
# 3           9,632                  45,086          10,197          10,436
# 4           4.70%                  -2.90%          -0.80%           1.10%
#
#          Milliken Mimico (includes Humber Bay Shores) Morningside  \
# 0             130                                  17         135
# 1  No Designation                      No Designation         NIA
# 2          26,572                              33,964      17,455
# 3          27,167                              26,541      17,587
# 4          -2.20%                              28.00%      -0.80%
#
#         Moss Park Mount Dennis Mount Olive-Silverstone-Jamestown  \
# 0              73          115                                 2
# 1  No Designation          NIA                               NIA
# 2          20,506       13,593                            32,954
# 3          16,306       13,145                            32,788
# 4          25.80%        3.40%                             0.50%
#
#   Mount Pleasant East Mount Pleasant West     New Toronto Newtonbrook East  \
# 0                  99                 104              18               50
# 1      No Designation      No Designation  No Designation   No Designation
# 2              16,775              29,658          11,463           16,097
# 3              15,982              28,593          10,900           16,423
# 4               5.00%               3.70%           5.20%           -2.00%
#
#   Newtonbrook West         Niagara North Riverdale North St. James Town  \
# 0               36              82              68                   74
# 1   No Designation  No Designation  No Designation       No Designation
# 2           23,831          31,180          11,916               18,615
# 3           23,052          21,274          12,191               17,832
# 4            3.40%          46.60%          -2.30%                4.40%
#
#   Oakridge Oakwood Village O'Connor-Parkview   Old East York  \
# 0      121             107                54              58
# 1      NIA  No Designation    No Designation  No Designation
# 2   13,845          21,210            18,675           9,233
# 3   13,497          21,073            18,316           9,118
# 4    2.60%           0.70%             2.00%           1.30%
#
#   Palmerston-Little Italy Parkwoods-Donalda Pelmo Park-Humberlea  \
# 0                      80                45                   23
# 1          No Designation    No Designation       No Designation
# 2                  13,826            34,805               10,722
# 3                  13,746            34,617                8,710
# 4                   0.60%             0.50%               23.10%
#
#   Playter Estates-Danforth   Pleasant View Princess-Rosethorn Regent Park  \
# 0                       67              46                 10          72
# 1           No Designation  No Designation     No Designation         NIA
# 2                    7,804          15,818             11,051      10,803
# 3                    7,653          16,144             11,197      10,007
# 4                    2.00%          -2.00%             -1.30%       8.00%
#
#   Rexdale-Kipling Rockcliffe-Smythe    Roncesvalles Rosedale-Moore Park  \
# 0               4               111              86                  98
# 1  No Designation               NIA  No Designation      No Designation
# 2          10,529            22,246          14,974              20,923
# 3          10,488            22,267          15,050              20,631
# 4           0.40%            -0.10%          -0.50%               1.40%
#
#             Rouge Runnymede-Bloor West Village  Rustic Scarborough Village  \
# 0             131                           89      28                 139
# 1  No Designation               No Designation     NIA                 NIA
# 2          46,496                       10,070   9,941              16,724
# 3          45,912                        9,632   9,951              16,609
# 4           1.30%                        4.50%  -0.10%               0.70%
#
#   South Parkdale South Riverdale St.Andrew-Windfields                 Steeles  \
# 0             85              70                   40                     116
# 1            NIA  No Designation       No Designation  Emerging Neighbourhood
# 2         21,849          27,876               17,812                  24,623
# 3         21,251          25,642               17,958                  25,017
# 4          2.80%           8.70%               -0.80%                  -1.60%
#
#   Stonegate-Queensway Tam O'Shanter-Sullivan Taylor-Massey     The Beaches  \
# 0                  16                    118            61              63
# 1      No Designation         No Designation           NIA  No Designation
# 2              25,051                 27,446        15,683          21,567
# 3              24,691                 27,398        15,594          21,130
# 4               1.50%                  0.20%         0.60%           2.10%
#
#   Thistletown-Beaumond Heights Thorncliffe Park Trinity-Bellwoods  \
# 0                            3               55                81
# 1                          NIA              NIA    No Designation
# 2                       10,360           21,108            16,556
# 3                       10,138           19,225            16,802
# 4                        2.20%            9.80%            -1.50%
#
#        University Victoria Village Waterfront Communities-The Island  \
# 0              79               43                                77
# 1  No Designation              NIA                    No Designation
# 2           7,607           17,510                            65,913
# 3           7,782           17,182                            43,361
# 4          -2.20%            1.90%                            52.00%
#
#   West Hill West Humber-Clairville     Westminster-Branson  Weston  \
# 0       136                      1                      35     113
# 1       NIA         No Designation  Emerging Neighbourhood     NIA
# 2    27,392                 33,312                  26,274  17,992
# 3    26,547                 34,100                  25,446  18,170
# 4     3.20%                 -2.30%                   3.30%  -1.00%
#
#   Weston-Pelham Park Wexford/Maryvale Willowdale East Willowdale West  \
# 0                 91              119              51              37
# 1                NIA   No Designation  No Designation  No Designation
# 2             11,098           27,917          50,434          16,936
# 3             12,010           27,018          45,041          15,004
# 4             -7.60%            3.30%          12.00%          12.90%
#
#   Willowridge-Martingrove-Richview  Woburn Woodbine Corridor Woodbine-Lumsden  \
# 0                                7     137                64               60
# 1                   No Designation     NIA    No Designation   No Designation
# 2                           22,156  53,485            12,541            7,865
# 3                           21,343  53,350            11,703            7,826
# 4                            3.80%   0.30%             7.20%            0.50%
#
#          Wychwood  Yonge-Eglinton  Yonge-St.Clair York University Heights  \
# 0              94             100              97                      27
# 1  No Designation  No Designation  No Designation                     NIA
# 2          14,349          11,817          12,528                  27,593
# 3          13,986          10,578          11,652                  27,713
# 4           2.60%          11.70%           7.50%                  -0.40%
#
#        Yorkdale-Glen Park
# 0                      31
# 1  Emerging Neighbourhood
# 2                  14,804
# 3                  14,687
# 4                   0.80%

# %% [markdown]
# ####First, some clean-up is required as well as transposing the dataset

# %%
to_data.drop(['_id', 'Category', 'Topic', 'Data Source'], axis=1, inplace=True)
to_data=to_data.transpose()
to_data.head()
# Out:
#                                               0                     1     \
# Characteristic                Neighbourhood Number  TSNS2020 Designation
# City of Toronto                                NaN                   NaN
# Agincourt North                                129        No Designation
# Agincourt South-Malvern West                   128        No Designation
# Alderwood                                       20        No Designation
#
#                                           2                 3     \
# Characteristic                Population, 2016  Population, 2011
# City of Toronto                      2,731,571         2,615,060
# Agincourt North                         29,113            30,279
# Agincourt South-Malvern West            23,757            21,988
# Alderwood                               12,054            11,904
#
#                                                      4     \
# Characteristic                Population Change 2011-2016
# City of Toronto                                     4.50%
# Agincourt North                                    -3.90%
# Agincourt South-Malvern West                        8.00%
# Alderwood                                           1.30%
#
#                                                  5     \
# Characteristic                Total private dwellings
# City of Toronto                             1,179,057
# Agincourt North                                 9,371
# Agincourt South-Malvern West                    8,535
# Alderwood                                       4,732
#
#                                                                        6     \
# Characteristic                Private dwellings occupied by usual residents
# City of Toronto                                                   1,112,929
# Agincourt North                                                       9,120
# Agincourt South-Malvern West                                          8,136
# Alderwood                                                             4,616
#
#                                                                  7     \
# Characteristic                Population density per square kilometre
# City of Toronto                                                 4,334
# Agincourt North                                                 3,929
# Agincourt South-Malvern West                                    3,034
# Alderwood                                                       2,435
#
#                                                         8     \
# Characteristic                Land area in square kilometres
# City of Toronto                                        630.2
# Agincourt North                                         7.41
# Agincourt South-Malvern West                            7.83
# Alderwood                                               4.95
#
#                                                9                    10    \
# Characteristic                Children (0-14 years)  Youth (15-24 years)
# City of Toronto                             398,135              340,270
# Agincourt North                               3,840                3,705
# Agincourt South-Malvern West                  3,075                3,360
# Alderwood                                     1,760                1,235
#
#                                                    11    \
# Characteristic                Working Age (25-54 years)
# City of Toronto                               1,229,555
# Agincourt North                                  11,305
# Agincourt South-Malvern West                      9,965
# Alderwood                                         5,220
#
#                                                       12    \
# Characteristic                Pre-retirement (55-64 years)
# City of Toronto                                    336,670
# Agincourt North                                      4,230
# Agincourt South-Malvern West                         3,265
# Alderwood                                            1,825
#
#                                              13                         14    \
# Characteristic                Seniors (65+ years)  Older Seniors (85+ years)
# City of Toronto                           426,945                     66,000
# Agincourt North                             6,045                        925
# Agincourt South-Malvern West                4,105                        555
# Alderwood                                   2,015                        320
#
#                                              15                    16    \
# Characteristic                Male: 0 to 04 years  Male: 05 to 09 years
# City of Toronto                            69,895                69,350
# Agincourt North                               660                   695
# Agincourt South-Malvern West                  575                   540
# Alderwood                                     360                   270
#
#                                               17                    18    \
# Characteristic                Male: 10 to 14 years  Male: 15 to 19 years
# City of Toronto                             64,945                74,240
# Agincourt North                                660                   840
# Agincourt South-Malvern West                   460                   780
# Alderwood                                      225                   285
#
#                                               19                    20    \
# Characteristic                Male: 20 to 24 years  Male: 25 to 29 years
# City of Toronto                             97,415               113,905
# Agincourt North                               1015                  1015
# Agincourt South-Malvern West                  1000                  1045
# Alderwood                                      355                   355
#
#                                               21                    22    \
# Characteristic                Male: 30 to 34 years  Male: 35 to 39 years
# City of Toronto                            108,895                94,070
# Agincourt North                                835                   680
# Agincourt South-Malvern West                   820                   625
# Alderwood                                      410                   455
#
#                                               23                    24    \
# Characteristic                Male: 40 to 44 years  Male: 45 to 49 years
# City of Toronto                             86,535                90,860
# Agincourt North                                760                   890
# Agincourt South-Malvern West                   610                   760
# Alderwood                                      420                   440
#
#                                               25                    26    \
# Characteristic                Male: 50 to 54 years  Male: 55 to 59 years
# City of Toronto                             98,735                88,145
# Agincourt North                               1160                  1060
# Agincourt South-Malvern West                   970                   850
# Alderwood                                      515                   540
#
#                                               27                    28    \
# Characteristic                Male: 60 to 64 years  Male: 65 to 69 years
# City of Toronto                             72,270                60,360
# Agincourt North                                925                   925
# Agincourt South-Malvern West                   710                   630
# Alderwood                                      390                   300
#
#                                               29                    30    \
# Characteristic                Male: 70 to 74 years  Male: 75 to 79 years
# City of Toronto                             42,320                32,730
# Agincourt North                                590                   490
# Agincourt South-Malvern West                   425                   350
# Alderwood                                      205                   155
#
#                                                 31                    32    \
# Characteristic                Female: 10 to 14 years  Male: 80 to 84 years
# City of Toronto                               62,165                25,670
# Agincourt North                                  595                   380
# Agincourt South-Malvern West                     475                   240
# Alderwood                                        255                   105
#
#                                               33                    34    \
# Characteristic                Male: 85 to 89 years  Male: 90 to 94 years
# City of Toronto                             15,665                 6,185
# Agincourt North                                210                   100
# Agincourt South-Malvern West                   155                    45
# Alderwood                                       65                    35
#
#                                               35                        36    \
# Characteristic                Male: 95 to 99 years  Male: 100 years and over
# City of Toronto                              1,280                       125
# Agincourt North                                 25                         0
# Agincourt South-Malvern West                    20                         0
# Alderwood                                       10                         0
#
#                                                37                      38    \
# Characteristic                Female: 0 to 04 years  Female: 05 to 09 years
# City of Toronto                              66,105                  65,680
# Agincourt North                                 620                     620
# Agincourt South-Malvern West                    530                     495
# Alderwood                                       320                     325
#
#                                                 39                      40    \
# Characteristic                Female: 15 to 19 years  Female: 20 to 24 years
# City of Toronto                               71,285                  97,330
# Agincourt North                                  865                     975
# Agincourt South-Malvern West                     690                     895
# Alderwood                                        290                     310
#
#                                                 41                      42    \
# Characteristic                Female: 25 to 29 years  Female: 30 to 34 years
# City of Toronto                              119,040                 115,675
# Agincourt North                                 1005                     935
# Agincourt South-Malvern West                     975                     835
# Alderwood                                        350                     430
#
#                                                 43                      44    \
# Characteristic                Female: 35 to 39 years  Female: 40 to 44 years
# City of Toronto                              102,240                  95,860
# Agincourt North                                  775                     910
# Agincourt South-Malvern West                     715                     745
# Alderwood                                        450                     445
#
#                                                 45                      46    \
# Characteristic                Female: 45 to 49 years  Female: 50 to 54 years
# City of Toronto                              100,065                 103,670
# Agincourt North                                 1060                    1290
# Agincourt South-Malvern West                     885                     975
# Alderwood                                        430                     515
#
#                                                 47                      48    \
# Characteristic                Female: 55 to 59 years  Female: 60 to 64 years
# City of Toronto                               94,660                  81,600
# Agincourt North                                 1165                    1070
# Agincourt South-Malvern West                     915                     795
# Alderwood                                        485                     400
#
#                                                 49                      50    \
# Characteristic                Female: 65 to 69 years  Female: 70 to 74 years
# City of Toronto                               70,180                  51,285
# Agincourt North                                  985                     690
# Agincourt South-Malvern West                     690                     450
# Alderwood                                        325                     210
#
#                                                 51                      52    \
# Characteristic                Female: 75 to 79 years  Female: 80 to 84 years
# City of Toronto                               43,430                  34,965
# Agincourt North                                  575                     485
# Agincourt South-Malvern West                     405                     350
# Alderwood                                        180                     210
#
#                                                 53                      54    \
# Characteristic                Female: 85 to 89 years  Female: 90 to 94 years
# City of Toronto                               25,135                  13,500
# Agincourt North                                  350                     160
# Agincourt South-Malvern West                     205                     100
# Alderwood                                        130                      70
#
#                                                 55    \
# Characteristic                Female: 95 to 99 years
# City of Toronto                                3,475
# Agincourt North                                   60
# Agincourt South-Malvern West                      20
# Alderwood                                          5
#
#                                                     56    \
# Characteristic                Female: 100 years and over
# City of Toronto                                      650
# Agincourt North                                       10
# Agincourt South-Malvern West                           0
# Alderwood                                              5
#
#                                                                            57    \
# Characteristic                Occupied private dwellings by structural type ...
# City of Toronto                                                       1,112,930
# Agincourt North                                                            9125
# Agincourt South-Malvern West                                               8135
# Alderwood                                                                  4620
#
#                                                  58    \
# Characteristic                  Single-detached house
# City of Toronto                               269,675
# Agincourt North                                  3345
# Agincourt South-Malvern West                     2790
# Alderwood                                        2840
#
#                                                                            59    \
# Characteristic                  Apartment in a building that has five or mor...
# City of Toronto                                                         493,275
# Agincourt North                                                            2120
# Agincourt South-Malvern West                                               3145
# Alderwood                                                                   255
#
#                                                    60    \
# Characteristic                  Other attached dwelling
# City of Toronto                                 349,880
# Agincourt North                                    3645
# Agincourt South-Malvern West                       2200
# Alderwood                                          1525
#
#                                                  61             62    \
# Characteristic                    Semi-detached house      Row house
# City of Toronto                                71,225         61,630
# Agincourt North                                   805           1440
# Agincourt South-Malvern West                      330            515
# Alderwood                                         545             85
#
#                                                            63    \
# Characteristic                    Apartment or flat in a duplex
# City of Toronto                                          48,540
# Agincourt North                                             645
# Agincourt South-Malvern West                                695
# Alderwood                                                   330
#
#                                                                            64    \
# Characteristic                    Apartment in a building that has fewer tha...
# City of Toronto                                                         165,630
# Agincourt North                                                             735
# Agincourt South-Malvern West                                                610
# Alderwood                                                                   560
#
#                                                          65    \
# Characteristic                    Other single-attached house
# City of Toronto                                         2,860
# Agincourt North                                            15
# Agincourt South-Malvern West                               65
# Alderwood                                                   0
#
#                                             66    \
# Characteristic                  Movable dwelling
# City of Toronto                               95
# Agincourt North                                5
# Agincourt South-Malvern West                   0
# Alderwood                                      0
#
#                                                               67    \
# Characteristic                Private households by household size
# City of Toronto                                          1,112,930
# Agincourt North                                               9125
# Agincourt South-Malvern West                                  8140
# Alderwood                                                     4620
#
#                                     68           69           70    \
# Characteristic                  1 person    2 persons    3 persons
# City of Toronto                  359,955      333,425      175,720
# Agincourt North                     1350         2370         1995
# Agincourt South-Malvern West        1610         2325         1680
# Alderwood                           1105         1440          885
#
#                                      71                   72    \
# Characteristic                  4 persons    5 or more persons
# City of Toronto                   146,580               97,245
# Agincourt North                      1750                 1645
# Agincourt South-Malvern West         1335                 1175
# Alderwood                             795                  390
#
#                                                                  73    \
# Characteristic                Number of persons in private households
# City of Toronto                                             2,691,665
# Agincourt North                                                 28820
# Agincourt South-Malvern West                                    23480
# Alderwood                                                       12030
#
#                                                  74    \
# Characteristic                 Average household size
# City of Toronto                                  2.42
# Agincourt North                                  3.16
# Agincourt South-Malvern West                     2.88
# Alderwood                                         2.6
#
#                                                                            75    \
# Characteristic                Marital status for the population aged 15 year...
# City of Toronto                                                       2,333,435
# Agincourt North                                                           25275
# Agincourt South-Malvern West                                              20690
# Alderwood                                                                 10285
#
#                                                         76           77    \
# Characteristic                  Married or living common law      Married
# City of Toronto                                    1,181,360    1,011,185
# Agincourt North                                        14200        13535
# Agincourt South-Malvern West                           11205        10400
# Alderwood                                               5735         4995
#
#                                                78    \
# Characteristic                    Living common law
# City of Toronto                             170,175
# Agincourt North                                 670
# Agincourt South-Malvern West                    805
# Alderwood                                       740
#
#                                                                  79    \
# Characteristic                  Not married and not living common law
# City of Toronto                                             1,152,075
# Agincourt North                                                 11075
# Agincourt South-Malvern West                                     9475
# Alderwood                                                        4550
#
#                                            80             81            82    \
# Characteristic                    Never married      Separated      Divorced
# City of Toronto                         806,270         68,715       152,000
# Agincourt North                            7355            570          1460
# Agincourt South-Malvern West               6605            460          1325
# Alderwood                                  3005            270           595
#
#                                      83    \
# Characteristic                    Widowed
# City of Toronto                   125,100
# Agincourt North                      1690
# Agincourt South-Malvern West         1080
# Alderwood                             685
#
#                                                                            84    \
# Characteristic                Census families in private households by famil...
# City of Toronto                                                         718,755
# Agincourt North                                                            8430
# Agincourt South-Malvern West                                               6650
# Alderwood                                                                  3480
#
#                                      85           86           87    \
# Characteristic                  2 persons    3 persons    4 persons
# City of Toronto                   344,110      174,600      143,250
# Agincourt North                      3570         2390         1875
# Agincourt South-Malvern West         2970         1835         1325
# Alderwood                            1605          900          755
#
#                                              88                          89    \
# Characteristic                  5 or more persons    Couples without children
# City of Toronto                            56,795                     250,085
# Agincourt North                               605                        2520
# Agincourt South-Malvern West                  520                        2095
# Alderwood                                     220                        1175
#
#                                                                            90    \
# Characteristic                Total number of census families in private hou...
# City of Toronto                                                         718,755
# Agincourt North                                                            8425
# Agincourt South-Malvern West                                               6640
# Alderwood                                                                  3490
#
#                                                  91                   92    \
# Characteristic                  Total couple families      Married couples
# City of Toronto                               566,155              481,125
# Agincourt North                                  6770                 6430
# Agincourt South-Malvern West                     5275                 4880
# Alderwood                                        2815                 2450
#
#                                                 93    \
# Characteristic                    Common-law couples
# City of Toronto                               85,030
# Agincourt North                                  335
# Agincourt South-Malvern West                     400
# Alderwood                                        370
#
#                                                                        94    \
# Characteristic                  Total lone-parent families by sex of parent
# City of Toronto                                                     152,600
# Agincourt North                                                        1655
# Agincourt South-Malvern West                                           1365
# Alderwood                                                               665
#
#                                            95               96    \
# Characteristic                    Female parent      Male parent
# City of Toronto                         128,545           24,055
# Agincourt North                            1295              355
# Agincourt South-Malvern West               1110              250
# Alderwood                                   535              135
#
#                                                                       97    \
# Characteristic                Couple census families in private households
# City of Toronto                                                    566,155
# Agincourt North                                                       6775
# Agincourt South-Malvern West                                          5280
# Alderwood                                                             2820
#
#                                                  98           99    \
# Characteristic                  Couples with children      1 child
# City of Toronto                               316,070      133,440
# Agincourt North                                  4250         1910
# Agincourt South-Malvern West                     3180         1485
# Alderwood                                        1645          710
#
#                                         100                     101   \
# Characteristic                    2 children      3 or more children
# City of Toronto                      130,765                  51,865
# Agincourt North                         1770                     560
# Agincourt South-Malvern West            1210                     480
# Alderwood                                725                     210
#
#                                                                            102   \
# Characteristic                Lone-parent census families in private households
# City of Toronto                                                         152,595
# Agincourt North                                                            1650
# Agincourt South-Malvern West                                               1360
# Alderwood                                                                   670
#
#                                    103           104   \
# Characteristic                  1 child    2 children
# City of Toronto                  94,025        41,160
# Agincourt North                    1040           485
# Agincourt South-Malvern West        860           345
# Alderwood                           430           190
#
#                                                         105   \
# Characteristic                  Non-census-family households
# City of Toronto                                      427,975
# Agincourt North                                         1645
# Agincourt South-Malvern West                            2060
# Alderwood                                               1290
#
#                                               106   \
# Characteristic                  3 or more children
# City of Toronto                             17,415
# Agincourt North                                125
# Agincourt South-Malvern West                   150
# Alderwood                                       40
#
#                                                                            107   \
# Characteristic                Persons not in census families in private hous...
# City of Toronto                                                         602,860
# Agincourt North                                                            3885
# Agincourt South-Malvern West                                               4005
# Alderwood                                                                  1930
#
#                                                               108   \
# Characteristic                Private households by household type
# City of Toronto                                          1,112,930
# Agincourt North                                               9130
# Agincourt South-Malvern West                                  8135
# Alderwood                                                     4615
#
#                                                         109   \
# Characteristic                  One-census-family households
# City of Toronto                                      653,360
# Agincourt North                                         6600
# Agincourt South-Malvern West                            5550
# Alderwood                                               3180
#
#                                                                  110   \
# Characteristic                    Without children in a census family
# City of Toronto                                               226,080
# Agincourt North                                                  1795
# Agincourt South-Malvern West                                     1660
# Alderwood                                                        1050
#
#                                                               111   \
# Characteristic                    With children in a census family
# City of Toronto                                            427,275
# Agincourt North                                               4795
# Agincourt South-Malvern West                                  3890
# Alderwood                                                     2130
#
#                                                              112   \
# Characteristic                  Multiple-census-family households
# City of Toronto                                            31,600
# Agincourt North                                               885
# Agincourt South-Malvern West                                  525
# Alderwood                                                     150
#
#                                                    113   \
# Characteristic                    One-person households
# City of Toronto                                 359,960
# Agincourt North                                    1350
# Agincourt South-Malvern West                       1615
# Alderwood                                          1105
#
#                                                                            114   \
# Characteristic                    Two-or-more person non-census-family house...
# City of Toronto                                                          68,010
# Agincourt North                                                             290
# Agincourt South-Malvern West                                                445
# Alderwood                                                                   185
#
#                                                                            115   \
# Characteristic                Total population (age 15+) by family character...
# City of Toronto                                                       2,294,785
# Agincourt North                                                          24,990
# Agincourt South-Malvern West                                             20,395
# Alderwood                                                                10,265
#
#                                                       116   \
# Characteristic                Persons living alone (total)
# City of Toronto                                    359,955
# Agincourt North                                      1,355
# Agincourt South-Malvern West                         1,625
# Alderwood                                            1,105
#
#                                                          117   \
# Characteristic                Persons living alone (per cent)
# City of Toronto                                        15.70%
# Agincourt North                                         5.40%
# Agincourt South-Malvern West                            8.00%
# Alderwood                                              10.80%
#
#                                                                       118   \
# Characteristic                Population age 65+ by family characteristics
# City of Toronto                                                    402,050
# Agincourt North                                                      5,780
# Agincourt South-Malvern West                                         3,850
# Alderwood                                                            2,005
#
#                                                               119   \
# Characteristic                Persons age 65+ living alone (total)
# City of Toronto                                            107,215
# Agincourt North                                                795
# Agincourt South-Malvern West                                   520
# Alderwood                                                      440
#
#                                                                  120   \
# Characteristic                Persons age 65+ living alone (per cent)
# City of Toronto                                                26.70%
# Agincourt North                                                13.80%
# Agincourt South-Malvern West                                   13.50%
# Alderwood                                                      22.00%
#
#                                                                       121   \
# Characteristic                Population age 85+ by family characteristics
# City of Toronto                                                     51,925
# Agincourt North                                                        735
# Agincourt South-Malvern West                                           440
# Alderwood                                                              320
#
#                                                               122   \
# Characteristic                Persons age 85+ living alone (total)
# City of Toronto                                             20,105
# Agincourt North                                                190
# Agincourt South-Malvern West                                    95
# Alderwood                                                      110
#
#                                                                  123   \
# Characteristic                Persons age 85+ living alone (per cent)
# City of Toronto                                                38.70%
# Agincourt North                                                25.90%
# Agincourt South-Malvern West                                   21.60%
# Alderwood                                                      34.40%
#
#                                                                         124   \
# Characteristic                Population age 20-34 by family characteristics
# City of Toronto                                                      648,685
# Agincourt North                                                        5,780
# Agincourt South-Malvern West                                           5,550
# Alderwood                                                              2,215
#
#                                                                            125   \
# Characteristic                Single young adults (age 20-34) living at home...
# City of Toronto                                                          86,935
# Agincourt North                                                              95
# Agincourt South-Malvern West                                                410
# Alderwood                                                                   110
#
#                                                                            126   \
# Characteristic                Single young adults (age 20-34) living at home...
# City of Toronto                                                          13.40%
# Agincourt North                                                           1.60%
# Agincourt South-Malvern West                                              7.40%
# Alderwood                                                                 5.00%
#
#                                                                            127   \
# Characteristic                Knowledge of official languages for the total ...
# City of Toronto                                                       2,704,415
# Agincourt North                                                          28,850
# Agincourt South-Malvern West                                             23,730
# Alderwood                                                                12,030
#
#                                         128            129   \
# Characteristic                  English only    French only
# City of Toronto                    2,323,235          2,725
# Agincourt North                       21,645             15
# Agincourt South-Malvern West          19,225              5
# Alderwood                             10,840              0
#
#                                               130   \
# Characteristic                  English and French
# City of Toronto                            245,695
# Agincourt North                              1,235
# Agincourt South-Malvern West                 1,060
# Alderwood                                      890
#
#                                                       131   \
# Characteristic                  Neither English nor French
# City of Toronto                                    132,765
# Agincourt North                                      5,945
# Agincourt South-Malvern West                         3,430
# Alderwood                                              295
#
#                                                                            132   \
# Characteristic                First official language spoken for the total p...
# City of Toronto                                                       2,704,420
# Agincourt North                                                          28,850
# Agincourt South-Malvern West                                             23,730
# Alderwood                                                                12,030
#
#                                    133   \
# Characteristic                  English
# City of Toronto               2,508,815
# Agincourt North                  22,595
# Agincourt South-Malvern West     19,990
# Alderwood                        11,570
#
#                                                                  134   \
# Characteristic                Official language minority (percentage)
# City of Toronto                                                 1.90%
# Agincourt North                                                 0.90%
# Agincourt South-Malvern West                                    1.00%
# Alderwood                                                       1.10%
#
#                                   135                   136   \
# Characteristic                  French    English and French
# City of Toronto                 39,795                24,865
# Agincourt North                    150                   220
# Agincourt South-Malvern West       150                   200
# Alderwood                          100                    65
#
#                                                       137   \
# Characteristic                  Neither English nor French
# City of Toronto                                    130,940
# Agincourt North                                      5,890
# Agincourt South-Malvern West                         3,395
# Alderwood                                              290
#
#                                                              138   \
# Characteristic                Official language minority (number)
# City of Toronto                                            52,230
# Agincourt North                                               265
# Agincourt South-Malvern West                                  245
# Alderwood                                                     130
#
#                                                                            139   \
# Characteristic                Mother tongue for the total population excludi...
# City of Toronto                                                       2,704,415
# Agincourt North                                                          28,845
# Agincourt South-Malvern West                                             23,740
# Alderwood                                                                12,035
#
#                                             140                     141   \
# Characteristic                  Single responses      Official languages
# City of Toronto                        2,598,230               1,411,345
# Agincourt North                           27,740                   7,185
# Agincourt South-Malvern West              22,720                   7,215
# Alderwood                                 11,675                   7,465
#
#                                        142           143   \
# Characteristic                      English        French
# City of Toronto                   1,375,905        35,440
# Agincourt North                       7,070           120
# Agincourt South-Malvern West          7,080           140
# Alderwood                             7,360           105
#
#                                                     144   \
# Characteristic                    Non-official languages
# City of Toronto                                1,186,885
# Agincourt North                                   20,570
# Agincourt South-Malvern West                      15,505
# Alderwood                                          4,205
#
#                                                     145   \
# Characteristic                      Aboriginal languages
# City of Toronto                                      420
# Agincourt North                                        5
# Agincourt South-Malvern West                           0
# Alderwood                                             10
#
#                                                       146   \
# Characteristic                        Algonquian languages
# City of Toronto                                        310
# Agincourt North                                          5
# Agincourt South-Malvern West                             0
# Alderwood                                                5
#
#                                              147   \
# Characteristic                          Blackfoot
# City of Toronto                                 5
# Agincourt North                                 0
# Agincourt South-Malvern West                    0
# Alderwood                                       0
#
#                                                              148   \
# Characteristic                          Cree-Montagnais languages
# City of Toronto                                                90
# Agincourt North                                                 0
# Agincourt South-Malvern West                                    0
# Alderwood                                                       0
#
#                                                                 149   \
# Characteristic                          Eastern Algonquian languages
# City of Toronto                                                   20
# Agincourt North                                                    0
# Agincourt South-Malvern West                                       0
# Alderwood                                                          0
#
#                                                                 150   \
# Characteristic                          Ojibway-Potawatomi languages
# City of Toronto                                                  200
# Agincourt North                                                    5
# Agincourt South-Malvern West                                       0
# Alderwood                                                          0
#
#                                                                 151   \
# Characteristic                          Algonquian languages, n.i.e.
# City of Toronto                                                    5
# Agincourt North                                                    0
# Agincourt South-Malvern West                                       0
# Alderwood                                                          0
#
#                                                       152   \
# Characteristic                        Athabaskan languages
# City of Toronto                                         15
# Agincourt North                                          0
# Agincourt South-Malvern West                             0
# Alderwood                                                0
#
#                                                                  153   \
# Characteristic                          Northern Athabaskan languages
# City of Toronto                                                    10
# Agincourt North                                                     0
# Agincourt South-Malvern West                                        0
# Alderwood                                                           0
#
#                                                           154   \
# Characteristic                            Babine (Wetsuwet'en)
# City of Toronto                                              0
# Agincourt North                                              0
# Agincourt South-Malvern West                                 0
# Alderwood                                                    0
#
#                                             155                  156   \
# Characteristic                            Beaver              Carrier
# City of Toronto                                0                    0
# ...
# Characteristic                    Other government transfers: Aggregate amou...
# City of Toronto                                                       2,329,868
# Agincourt North                                                          20,627
# Agincourt South-Malvern West                                             17,627
# Alderwood                                                                 7,489
#
#                                                                            2343  \
# Characteristic                      Social assistance benefits: Population w...
# City of Toronto                                                         132,255
# Agincourt North                                                             815
# Agincourt South-Malvern West                                                815
# Alderwood                                                                   285
#
#                                                                            2344  \
# Characteristic                      Social assistance benefits: Average amou...
# City of Toronto                                                           9,538
# Agincourt North                                                           8,602
# Agincourt South-Malvern West                                              8,926
# Alderwood                                                                 9,642
#
#                                                                            2345  \
# Characteristic                      Social assistance benefits: Aggregate am...
# City of Toronto                                                       1,261,440
# Agincourt North                                                           7,011
# Agincourt South-Malvern West                                              7,275
# Alderwood                                                                 2,748
#
#                                                                            2346  \
# Characteristic                      Workers' compensation benefits: Populati...
# City of Toronto                                                          25,140
# Agincourt North                                                             135
# Agincourt South-Malvern West                                                160
# Alderwood                                                                   240
#
#                                                                            2347  \
# Characteristic                      Goods and services tax (GST) credit and ...
# City of Toronto                                                       1,007,670
# Agincourt North                                                          12,930
# Agincourt South-Malvern West                                             10,195
# Alderwood                                                                 3,520
#
#                                                                            2348  \
# Characteristic                      Goods and services tax (GST) credit and ...
# City of Toronto                                                             343
# Agincourt North                                                             356
# Agincourt South-Malvern West                                                341
# Alderwood                                                                   327
#
#                                                                            2349  \
# Characteristic                      Goods and services tax (GST) credit and ...
# City of Toronto                                                         345,818
# Agincourt North                                                           4,606
# Agincourt South-Malvern West                                              3,475
# Alderwood                                                                 1,150
#
#                                                                            2350  \
# Characteristic                      Government transfers not included elsewh...
# City of Toronto                                                         909,400
# Agincourt North                                                          11,680
# Agincourt South-Malvern West                                              8,950
# Alderwood                                                                 3,410
#
#                                                                            2351  \
# Characteristic                      Government transfers not included elsewh...
# City of Toronto                                                             420
# Agincourt North                                                             514
# Agincourt South-Malvern West                                                452
# Alderwood                                                                   342
#
#                                                                            2352  \
# Characteristic                      Government transfers not included elsewh...
# City of Toronto                                                         381,968
# Agincourt North                                                           6,006
# Agincourt South-Malvern West                                              4,049
# Alderwood                                                                 1,166
#
#                                                                        2353  \
# Characteristic                  After-tax income: Population with an amount
# City of Toronto                                                   2,187,505
# Agincourt North                                                      23,505
# Agincourt South-Malvern West                                         19,370
# Alderwood                                                             9,920
#
#                                                                 2354  \
# Characteristic                  After-tax income: Average amount ($)
# City of Toronto                                               41,462
# Agincourt North                                               26,955
# Agincourt South-Malvern West                                  27,928
# Alderwood                                                     39,159
#
#                                                                       2355  \
# Characteristic                  After-tax income: Aggregate amount ($'000)
# City of Toronto                                                 90,697,781
# Agincourt North                                                    633,574
# Agincourt South-Malvern West                                       540,969
# Alderwood                                                          388,460
#
#                                                                    2356  \
# Characteristic                  Income taxes: Population with an amount
# City of Toronto                                               1,373,645
# Agincourt North                                                  12,025
# Agincourt South-Malvern West                                     10,480
# Alderwood                                                         7,255
#
#                                                             2357  \
# Characteristic                  Income taxes: Average amount ($)
# City of Toronto                                           17,197
# Agincourt North                                            6,726
# Agincourt South-Malvern West                               7,185
# Alderwood                                                 11,626
#
#                                                                   2358  \
# Characteristic                  Income taxes: Aggregate amount ($'000)
# City of Toronto                                             23,622,931
# Agincourt North                                                 80,881
# Agincourt South-Malvern West                                    75,294
# Alderwood                                                       84,349
#
#                                                                         2359  \
# Characteristic                    Net federal tax: Population with an amount
# City of Toronto                                                    1,271,925
# Agincourt North                                                       10,910
# Agincourt South-Malvern West                                           9,555
# Alderwood                                                              6,860
#
#                                                                  2360  \
# Characteristic                    Net federal tax: Average amount ($)
# City of Toronto                                                11,542
# Agincourt North                                                 4,795
# Agincourt South-Malvern West                                    5,102
# Alderwood                                                       7,895
#
#                                                                        2361  \
# Characteristic                    Net federal tax: Aggregate amount ($'000)
# City of Toronto                                                  14,680,842
# Agincourt North                                                      52,315
# Agincourt South-Malvern West                                         48,753
# Alderwood                                                            54,161
#
#                                                                            2362  \
# Characteristic                    Provincial and territorial income taxes: P...
# City of Toronto                                                       1,339,410
# Agincourt North                                                          11,585
# Agincourt South-Malvern West                                             10,060
# Alderwood                                                                 7,060
#
#                                                                            2363  \
# Characteristic                    Provincial and territorial income taxes: A...
# City of Toronto                                                           6,676
# Agincourt North                                                           2,472
# Agincourt South-Malvern West                                              2,642
# Alderwood                                                                 4,274
#
#                                                                            2364  \
# Characteristic                    Provincial and territorial income taxes: A...
# City of Toronto                                                       8,942,171
# Agincourt North                                                          28,636
# Agincourt South-Malvern West                                             26,579
# Alderwood                                                                30,171
#
#                                                                            2365  \
# Characteristic                Total - Mobility status 1 year ago - 25% sampl...
# City of Toronto                                                       2,663,555
# Agincourt North                                                          28,595
# Agincourt South-Malvern West                                             23,235
# Alderwood                                                                11,860
#
#                                       2366      2367              2368  \
# Characteristic                  Non-movers    Movers      Non-migrants
# City of Toronto                  2,284,060   379,495           253,780
# Agincourt North                     25,775     2,830             1,875
# Agincourt South-Malvern West        20,155     3,070             2,180
# Alderwood                           10,895       965               640
#
#                                       2369                     2370  \
# Characteristic                    Migrants        Internal migrants
# City of Toronto                    125,715                   65,770
# Agincourt North                        950                      345
# Agincourt South-Malvern West           895                      395
# Alderwood                              330                      260
#
#                                                           2371  \
# Characteristic                        Intraprovincial migrants
# City of Toronto                                         49,990
# Agincourt North                                            275
# Agincourt South-Malvern West                               320
# Alderwood                                                  220
#
#                                                           2372  \
# Characteristic                        Interprovincial migrants
# City of Toronto                                         15,780
# Agincourt North                                             75
# Agincourt South-Malvern West                                90
# Alderwood                                                   40
#
#                                                  2373  \
# Characteristic                      External migrants
# City of Toronto                                59,945
# Agincourt North                                   605
# Agincourt South-Malvern West                      490
# Alderwood                                          70
#
#                                                                            2374  \
# Characteristic                Total - Mobility status 5 years ago - 25% samp...
# City of Toronto                                                       2,556,120
# Agincourt North                                                          27,490
# Agincourt South-Malvern West                                             22,325
# Alderwood                                                                11,370
#
#                                       2375       2376              2377  \
# Characteristic                  Non-movers     Movers      Non-migrants
# City of Toronto                  1,516,110  1,040,015           639,060
# Agincourt North                     18,865      8,610             5,445
# Agincourt South-Malvern West        13,565      8,775             5,610
# Alderwood                            8,235      3,130             2,200
#
#                                       2378                     2379  \
# Characteristic                    Migrants        Internal migrants
# City of Toronto                    400,950                  184,120
# Agincourt North                      3,170                      880
# Agincourt South-Malvern West         3,145                      980
# Alderwood                              925                      680
#
#                                                           2380  \
# Characteristic                        Intraprovincial migrants
# City of Toronto                                        141,135
# Agincourt North                                            735
# Agincourt South-Malvern West                               760
# Alderwood                                                  615
#
#                                                           2381  \
# Characteristic                        Interprovincial migrants
# City of Toronto                                         42,985
# Agincourt North                                            135
# Agincourt South-Malvern West                               220
# Alderwood                                                   70
#
#                                                  2382
# Characteristic                      External migrants
# City of Toronto                               216,835
# Agincourt North                                 2,280
# Agincourt South-Malvern West                    2,170
# Alderwood                                         245

# %% [markdown]
# ####There is a lot of interesting info here, I will pick a few related to population, income and French speakers

# %%
#French restaurant
to_selected=to_data[[2, 4, 7, 129, 130, 2272]]
to_selected.head()
# Out:
#                                           2                            4     \
# Characteristic                Population, 2016  Population Change 2011-2016
# City of Toronto                      2,731,571                        4.50%
# Agincourt North                         29,113                       -3.90%
# Agincourt South-Malvern West            23,757                        8.00%
# Alderwood                               12,054                        1.30%
#
#                                                                  7     \
# Characteristic                Population density per square kilometre
# City of Toronto                                                 4,334
# Agincourt North                                                 3,929
# Agincourt South-Malvern West                                    3,034
# Alderwood                                                       2,435
#
#                                        129                   130   \
# Characteristic                  French only    English and French
# City of Toronto                       2,725               245,695
# Agincourt North                          15                 1,235
# Agincourt South-Malvern West              5                 1,060
# Alderwood                                 0                   890
#
#                                                           2272
# Characteristic                Total income: Average amount ($)
# City of Toronto                                         52,268
# Agincourt North                                         30,414
# Agincourt South-Malvern West                            31,825
# Alderwood                                               47,709

# %% [markdown]
# ####The first row should be the column names:

# %%
to_selected.reset_index(inplace=True)
to_selected.columns = to_selected.iloc[0]
to_selected = to_selected[1:]
to_selected.head()
# Out:
# 0                Characteristic Population, 2016 Population Change 2011-2016  \
# 1               City of Toronto        2,731,571                       4.50%
# 2               Agincourt North           29,113                      -3.90%
# 3  Agincourt South-Malvern West           23,757                       8.00%
# 4                     Alderwood           12,054                       1.30%
# 5                         Annex           30,526                       4.60%
#
# 0 Population density per square kilometre   French only   English and French  \
# 1                                   4,334         2,725              245,695
# 2                                   3,929            15                1,235
# 3                                   3,034             5                1,060
# 4                                   2,435             0                  890
# 5                                  10,863            10                6,015
#
# 0 Total income: Average amount ($)
# 1                           52,268
# 2                           30,414
# 3                           31,825
# 4                           47,709
# 5                          112,766

# %%
to_selected.dtypes
# Out:
# 0
# Characteristic                             object
# Population, 2016                           object
# Population Change 2011-2016                object
# Population density per square kilometre    object
#   French only                              object
#   English and French                       object
# Total income: Average amount ($)           object
# dtype: object

# %% [markdown]
# ####Several of the columns are of dtype object so have to be changed to integers. I found it easiest to first convert them to floats, then integers:

# %%
#Since the columns where of dtype object, I first had to change them to floats, then ints
to_selected["Population, 2016"]=to_selected["Population, 2016"].str.replace(',', '').astype(float)
to_selected["Population Change 2011-2016"]=to_selected["Population Change 2011-2016"].str.replace('%', '').astype(float)
to_selected["Population density per square kilometre"]=to_selected["Population density per square kilometre"].str.replace(',', '').astype(float)
to_selected["  French only"]=to_selected["  French only"].str.replace(',', '').astype(float)
to_selected["  English and French"]=to_selected["  English and French"].str.replace(',', '').astype(float)
to_selected["Total income: Average amount ($)"]=to_selected["Total income: Average amount ($)"].str.replace(',', '').astype(float)
to_selected["Population, 2016"]=to_selected["Population, 2016"].astype("int64")
to_selected["Population Change 2011-2016"]=to_selected["Population Change 2011-2016"].astype("int64")
to_selected["Population density per square kilometre"]=to_selected["Population density per square kilometre"].astype("int64")
to_selected["  French only"]=to_selected["  French only"].astype("int64")
to_selected["  English and French"]=to_selected["  English and French"].astype("int64")
to_selected["Total income: Average amount ($)"]=to_selected["Total income: Average amount ($)"].astype("int64")
to_selected.dtypes
# Out:
# 0
# Characteristic                             object
# Population, 2016                            int64
# Population Change 2011-2016                 int64
# Population density per square kilometre     int64
#   French only                               int64
#   English and French                        int64
# Total income: Average amount ($)            int64
# dtype: object

# %% [markdown]
# ####Let's add a column with the percentage of French-speakers in the neighborhood

# %%
to_selected["French speaking (%)"]=((to_selected["  French only"]+to_selected["  English and French"])/to_selected["Population, 2016"])*100
to_selected.head()
# Out:
# 0                Characteristic  Population, 2016  \
# 1               City of Toronto           2731571
# 2               Agincourt North             29113
# 3  Agincourt South-Malvern West             23757
# 4                     Alderwood             12054
# 5                         Annex             30526
#
# 0  Population Change 2011-2016  Population density per square kilometre  \
# 1                            4                                     4334
# 2                           -3                                     3929
# 3                            8                                     3034
# 4                            1                                     2435
# 5                            4                                    10863
#
# 0    French only    English and French  Total income: Average amount ($)  \
# 1           2725                245695                             52268
# 2             15                  1235                             30414
# 3              5                  1060                             31825
# 4              0                   890                             47709
# 5             10                  6015                            112766
#
# 0  French speaking (%)
# 1             9.094400
# 2             4.293615
# 3             4.482889
# 4             7.383441
# 5            19.737273

# %% [markdown]
# ####Some further cleaning:

# %%
to_selected["Latitude"]=''                                                                                    #adding latitude column
to_selected["Longitude"]=''                                                                                   #adding longitude column
to_selected=to_selected[['Characteristic', 'Population Change 2011-2016',
       'Population density per square kilometre', 'Total income: Average amount ($)',
       'French speaking (%)', 'Latitude', 'Longitude']]                                                       #removing some columns and changing orders
to_selected=to_selected.rename(columns = {'Characteristic': 'Neighborhood', 
                                          "Population Change 2011-2016": "+/- Population(%)",
                                          "Population density per square kilometre": "Population/sqkm",
                                          "  French only": "French only", 
                                          "  English and French": "English and French", 
                                          "Total income: Average amount ($)":"Average income ($}"})            #changing name of column to neighborhood 
to_selected.drop([1], inplace=True)
to_selected.reset_index(inplace=True)
del to_selected['index']                                                                                      #fixing the index
to_selected.head()
# Out:
# 0                  Neighborhood  +/- Population(%)  Population/sqkm  \
# 0               Agincourt North                 -3             3929
# 1  Agincourt South-Malvern West                  8             3034
# 2                     Alderwood                  1             2435
# 3                         Annex                  4            10863
# 4             Banbury-Don Mills                  2             2775
#
# 0  Average income ($}  French speaking (%) Latitude Longitude
# 0               30414             4.293615
# 1               31825             4.482889
# 2               47709             7.383441
# 3              112766            19.737273
# 4               67757            10.525366

# %% [markdown]
# ###2. Geocoding for adresses and coordinates
# ####Geopy's geolocator is used, first to get geocodes from neighborhoods:

# %%
geolocator = Nominatim(user_agent="foursquare_agent")
to_selected['full_address'] = to_selected.Neighborhood + ", Toronto, ON"
to_selected['gcode'] = to_selected.full_address.apply(geolocator.geocode)
to_selected['gcode']
# Out:
# 0      (Agincourt North, Scarborough North, Scarborou...
# 1      (CTV Agincourt Studios, 9, Channel Nine Court,...
# 2      (Alderwood, Etobicoke—Lakeshore, Etobicoke, To...
# 3      (The Annex, University—Rosedale, Old Toronto, ...
# 4      (Banbury Road, York Mills Road, Don Valley Wes...
# 5      (Former Bathurst Manor Plaza grounds, York Cen...
# 6      (Bay Street, Yorkville, University—Rosedale, O...
# 7      (Bayview Village, Don Valley North, North York...
# 8      (Bayview Woods-Steeles, Don Valley North, Nort...
# 9                                                   None
# 10                                                  None
# 11     (Bendale, Scarborough Centre, Scarborough, Tor...
# 12                                                  None
# 13     (Black Creek, York, North York, Toronto, Golde...
# 14                                                  None
# 15                                                  None
# 16                                                  None
# 17     (Broadview North, Toronto—Danforth, East York,...
# 18                                                  None
# 19     (Cabbagetown Brew, 552, Parliament Street, Cab...
# 20                                                  None
# 21     (Casa Loma, 1, Austin Terrace, Tarragon Villag...
# 22     (Centennial, Scarborough—Rouge Park, Scarborou...
# 23     (Bloor-Yonge, 2, Bloor Street East, Yorkville,...
# 24                                                  None
# 25     (Clanton Park Road, Wilson Heights, York Centr...
# 26     (Cliffcrest, Scarborough Southwest, Scarboroug...
# 27     (Corso Italia, Davenport, Old Toronto, Toronto...
# 28     (Danforth, 213, Main Street, Danforth East, Be...
# 29     (Danforth East, Beaches—East York, Old Toronto...
# 30     (Don Valley Village, Don Valley North, North Y...
# 31     (Dorset Park, Scarborough Centre, Scarborough,...
# 32                                                  None
# 33                                                  None
# 34     (Dufferin Grove, Davenport, Old Toronto, Toron...
# 35     (East End, Toronto—Danforth, Old Toronto, Toro...
# 36     (Edenbridge Drive, Humber Valley, Etobicoke Ce...
# 37     (Eglinton, 2995, Eglinton Avenue East, Scarbor...
# 38     (The Elms Junior Middle School, 45, Golfdown D...
# 39     (Englemount Avenue, Glen Park, Eglinton—Lawren...
# 40                                                  None
# 41     (Etobicoke Civic Centre, 399, The West Mall, E...
# 42     (Flemingdon Park, Don Valley East, North York,...
# 43     (Forest Hill, Toronto—St. Paul's, Old Toronto,...
# 44     (Forest Hill, Toronto—St. Paul's, Old Toronto,...
# 45     (Jane-Finch Mall, 1911, Finch Avenue West, Jan...
# 46                                                  None
# 47     (Guildwood, Westlake Road, Guildwood Village, ...
# 48     (Henry Farm, Don Valley North, North York, Tor...
# 49     (High Park North, Parkdale—High Park, Old Toro...
# 50     (Morningside-High Park Presbyterian Church, 4,...
# 51     (Highland Creek, Scarborough—Rouge Park, Scarb...
# 52     (Hillcrest Village, Toronto—St. Paul's, Old To...
# 53     (Vista Humber Drive, Humber Heights, Etobicoke...
# 54     (Humber Summit, Humber River—Black Creek, Nort...
# 55                                                  None
# 56     (Humewood Drive, Humewood, Toronto—St. Paul's,...
# 57     (Ionview, Scarborough Centre, Scarborough, Tor...
# 58     (Islington, 1240, Islington Avenue, Islington ...
# 59     (The Junction, Parkdale—High Park, Old Toronto...
# 60     (Keelesdale, Eglinton Avenue West, Keelesdale,...
# 61     (Kennedy Park, Scarborough Southwest, Scarboro...
# 62                                                  None
# 63                                                  None
# 64     (The Kingsway, Etobicoke—Lakeshore, Etobicoke,...
# 65                                                  None
# 66     (L'Amoreaux, Scarborough—Agincourt, Scarboroug...
# 67     (Lansing, Willowdale, North York, Toronto, Gol...
# 68     (Lawrence Park, Don Valley West, Old Toronto, ...
# 69     (Lawrence Park, Don Valley West, Old Toronto, ...
# 70     (Leaside Therapy Centre, McRae Drive, Leaside,...
# 71     (Little Portugal, Old Toronto, Toronto, Golden...
# 72     (Long Branch, Etobicoke—Lakeshore, Etobicoke, ...
# 73     (Malvern, Scarborough—Rouge Park, Scarborough,...
# 74     (Maple Leaf, York South—Weston, North York, To...
# 75     (Markland Wood Golf Club, 245, Markland Drive,...
# 76     (Milliken, 39, Redlea Avenue, Scarborough—Agin...
# 77                                                  None
# 78     (Morningside, Scarborough—Guildwood, Scarborou...
# 79     (Moss Park, Toronto Centre, Old Toronto, Toron...
# 80     (Mount Dennis, York South—Weston, York, Toront...
# 81                                                  None
# 82     (Mount Pleasant, Eglinton Avenue East, Davisvi...
# 83     (Mount Pleasant, Eglinton Avenue East, Davisvi...
# 84     (New Toronto, Etobicoke—Lakeshore, Etobicoke, ...
# 85     (Newtonbrook, Willowdale, North York, Toronto,...
# 86     (Newtonbrook, Willowdale, North York, Toronto,...
# 87     (Niagara, Spadina—Fort York, Old Toronto, Toro...
# 88     (Riverdale, Toronto—Danforth, Old Toronto, Tor...
# 89     (St. James Town, Toronto Centre, Old Toronto, ...
# 90     (Oakridge, Scarborough Southwest, Scarborough,...
# 91     (Oakwood, Davenport, York, Toronto, Golden Hor...
# 92     (O'Connor Drive, Woodbine Heights, Beaches—Eas...
# 93     (York University, Keele Campus, Haynes Avenue,...
# 94     (Palmerston Boulevard, Harbord Village, Univer...
# 95                                                  None
# 96                                                  None
# 97     (Playter Estates, Toronto—Danforth, Old Toront...
# 98     (Pleasant View, Don Valley North, North York, ...
# 99                                                  None
# 100    (Regent Park, Toronto Centre, Old Toronto, Tor...
# 101    (DUCA, 2184, Kipling Avenue, Rexdale, Etobicok...
# 102                                                 None
# 103    (Roncesvalles, Parkdale—High Park, Old Toronto...
# 104    (Moore Park, University—Rosedale, Old Toronto,...
# 105    (Rouge, Scarborough—Rouge Park, Scarborough, T...
# 106    (Runnymede, Bloor Street West, High Park North...
# 107    (Rustic Park, York South—Weston, North York, T...
# 108    (Scarborough Village, Scarborough—Guildwood, S...
# 109    (Parkdale—High Park, Old Toronto, Toronto, Gol...
# 110    (Riverdale, Toronto—Danforth, Old Toronto, Tor...
# 111    (St. Andrew, University Avenue, Financial Dist...
# 112    (Steeles, Scarborough—Agincourt, Scarborough, ...
# 113    (Goodfella Stone, 1208, The Queensway, Etobico...
# 114                                                 None
# 115    (Taylor Massey Creek, Scarborough Southwest, S...
# 116    (The Beaches, Beaches—East York, Old Toronto, ...
# 117                                                 None
# 118    (Thorncliffe Park, Don Valley West, East York,...
# 119    (Trinity Bellwoods Park, Spadina—Fort York, Ol...
# 120    (University of Toronto, Wellesley-Hoskin Cycle...
# 121    (Victoria Village, Don Valley East, North York...
# 122    (Tribute Communities Recital Hall, York Boulev...
# 123    (West Hill, Scarborough—Guildwood, Scarborough...
# 124    (West Humber-Clairville, Etobicoke, Toronto, G...
# 125                                                 None
# 126    (Weston, York South—Weston, York, Toronto, Gol...
# 127                                                 None
# 128                                                 None
# 129    (Willowdale, North York, Toronto, Golden Horse...
# 130    (Willowdale, North York, Toronto, Golden Horse...
# 131                                                 None
# 132    (Woburn, Scarborough—Guildwood, Scarborough, T...
# 133                                                 None
# 134                                                 None
# 135    (Wychwood, St. Clair Avenue West, Hillcrest Vi...
# 136    (Yonge & Eglinton, Toronto—St. Paul's, Old Tor...
# 137    (Yonge Street, St. Clair Avenue West, Deer Par...
# 138    (York University, 1, York Gate Boulevard, Jane...
# 139    (Yorkdale Fine Cars, Wingold Avenue, Glen Park...
# Name: gcode, dtype: object

# %% [markdown]
# ####Some geocodes were not found, these are moved from to_selected to a separate dataframe (to_missing):

# %%
to_missing = to_selected[to_selected["gcode"].isna()]
to_missing.reset_index(inplace=True)
del to_missing["index"]
to_selected.dropna(subset = ['gcode'], inplace=True)

# %% [markdown]
# ####Now we can get the coordinates for the to_selected dataframe:

# %%
to_selected['Latitude'] = [g.latitude for g in to_selected.gcode]
to_selected['Longitude'] = [g.longitude for g in to_selected.gcode]

# %% [markdown]
# ####For the neighborhoods without g.adresses (in to_missing), coordinates were manually found by googling and subsequently added:

# %%
for row in to_missing.itertuples():
    if to_missing.iloc[row.Index, 0] == 'Agincourt South-Malvern West' :
        to_missing.iloc[row.Index, 5] =  43.7925
        to_missing.iloc[row.Index, 6] =  -79.283889
    elif to_missing.iloc[row.Index, 0] == 'Bedford Park-Nortown' :
        to_missing.iloc[row.Index, 5] =  43.73
        to_missing.iloc[row.Index, 6] =  -79.411
    elif to_missing.iloc[row.Index, 0] == 'Cabbagetown-South St. James Town' :
        to_missing.iloc[row.Index, 5] =  43.620543
        to_missing.iloc[row.Index, 6] =  -79.47793
    elif to_missing.iloc[row.Index, 0] == 'Downsview-Roding-CFB' :
        to_missing.iloc[row.Index, 5] =  43.732222
        to_missing.iloc[row.Index, 6] =  -79.493333
    elif to_missing.iloc[row.Index, 0] == 'Mimico (includes Humber Bay Shores)' :
        to_missing.iloc[row.Index, 5] =  43.612778
        to_missing.iloc[row.Index, 6] =  -79.494167
    elif to_missing.iloc[row.Index, 0] == 'Beechborough-Greenbrook' :
        to_missing.iloc[row.Index, 5] =  43.6943
        to_missing.iloc[row.Index, 6] =  -79.4748
    elif to_missing.iloc[row.Index, 0] == 'Birchcliffe-Cliffside' :
        to_missing.iloc[row.Index, 5] =  43.7089
        to_missing.iloc[row.Index, 6] =  -79.2485
    elif to_missing.iloc[row.Index, 0] == 'Bridle Path-Sunnybrook-York Mills' :
        to_missing.iloc[row.Index, 5] =  43.7359
        to_missing.iloc[row.Index, 6] =  -79.3719
    elif to_missing.iloc[row.Index, 0] == 'Brookhaven-Amesbury' :
        to_missing.iloc[row.Index, 5] =  43.6969
        to_missing.iloc[row.Index, 6] =  -79.4938
    elif to_missing.iloc[row.Index, 0] == 'Clairlea-Birchmount' :
        to_missing.iloc[row.Index, 5] =  43.7162
        to_missing.iloc[row.Index, 6] =  -79.2828
    elif to_missing.iloc[row.Index, 0] == 'Dovercourt-Wallace Emerson-Junction' :
        to_missing.iloc[row.Index, 5] =  43.663
        to_missing.iloc[row.Index, 6] =  -79.441
    elif to_missing.iloc[row.Index, 0] == 'Eringate-Centennial-West Deane' :
        to_missing.iloc[row.Index, 5] =  43.6599
        to_missing.iloc[row.Index, 6] =  -79.5833
    elif to_missing.iloc[row.Index, 0] == 'Greenwood-Coxwell' :
        to_missing.iloc[row.Index, 5] =  43.6721
        to_missing.iloc[row.Index, 6] =  -79.3228
    elif to_missing.iloc[row.Index, 0] == 'Humbermede' :
        to_missing.iloc[row.Index, 5] =  43.746297
        to_missing.iloc[row.Index, 6] =  -79.541186
    elif to_missing.iloc[row.Index, 0] == 'Islington-City Centre West' :
        to_missing.iloc[row.Index, 5] =  43.6309
        to_missing.iloc[row.Index, 6] =  -79.5435
    elif to_missing.iloc[row.Index, 0] == 'Leaside-Bennington' :
        to_missing.iloc[row.Index, 5] =  43.708
        to_missing.iloc[row.Index, 6] =  -79.368
    elif to_missing.iloc[row.Index, 0] == 'Mount Olive-Silverstone-Jamestown' :
        to_missing.iloc[row.Index, 5] =  43.739722
        to_missing.iloc[row.Index, 6] =  -79.580278
    elif to_missing.iloc[row.Index, 0] == 'Parkwoods-Donalda' :
        to_missing.iloc[row.Index, 5] =  43.7528
        to_missing.iloc[row.Index, 6] =  -79.3264
    elif to_missing.iloc[row.Index, 0] == 'Playter Estates-Danforth' :
        to_missing.iloc[row.Index, 5] =  43.68
        to_missing.iloc[row.Index, 6] =  -79.349
    elif to_missing.iloc[row.Index, 0] == 'Princess-Rosethorn' :
        to_missing.iloc[row.Index, 5] =  43.6700
        to_missing.iloc[row.Index, 6] =  -79.5477
    elif to_missing.iloc[row.Index, 0] == 'Rockcliffe-Smythe' :
        to_missing.iloc[row.Index, 5] =  43.6769
        to_missing.iloc[row.Index, 6] =  -79.4894
    elif to_missing.iloc[row.Index, 0] == 'St.Andrew-Windfields' :
        to_missing.iloc[row.Index, 5] =  43.7548
        to_missing.iloc[row.Index, 6] =  -79.3855
    elif to_missing.iloc[row.Index, 0] == "Tam O'Shanter-Sullivan" :
        to_missing.iloc[row.Index, 5] =  43.7811
        to_missing.iloc[row.Index, 6] =  -79.2981
    elif to_missing.iloc[row.Index, 0] == "Thistletown-Beaumond Heights" :
        to_missing.iloc[row.Index, 5] =  43.737222
        to_missing.iloc[row.Index, 6] =  -79.565278
    elif to_missing.iloc[row.Index, 0] == "Westminster-Branson" :
        to_missing.iloc[row.Index, 5] =  43.7856
        to_missing.iloc[row.Index, 6] =  -79.4511
    elif to_missing.iloc[row.Index, 0] == "Wexford/Maryvale" :
        to_missing.iloc[row.Index, 5] =  43.7613
        to_missing.iloc[row.Index, 6] =  -79.3008
    elif to_missing.iloc[row.Index, 0] == "Willowridge-Martingrove-Richview" :
        to_missing.iloc[row.Index, 5] =  43.6762
        to_missing.iloc[row.Index, 6] =  -79.5705
    elif to_missing.iloc[row.Index, 0] == "Bay Street Corridor" :
        to_missing.iloc[row.Index, 5] =  43.657291
        to_missing.iloc[row.Index, 6] =  -79.384302 
    elif to_missing.iloc[row.Index, 0] == "Bathurst Manor" :
        to_missing.iloc[row.Index, 5] =  43.7628
        to_missing.iloc[row.Index, 6] =  -79.4569
    elif to_missing.iloc[row.Index, 0] == "Bay Street Corridor" :
        to_missing.iloc[row.Index, 5] =  43.7303
        to_missing.iloc[row.Index, 6] =  -79.384302
    elif to_missing.iloc[row.Index, 0] == "Bedford" :
        to_missing.iloc[row.Index, 5] =  43.7628
        to_missing.iloc[row.Index, 6] =  -79.4114
    elif to_missing.iloc[row.Index, 0] == "Black Creek" :
        to_missing.iloc[row.Index, 5] =  43.669444
        to_missing.iloc[row.Index, 6] =  -79.511389
    elif to_missing.iloc[row.Index, 0] == "Briar Hill-Belgravia" :
        to_missing.iloc[row.Index, 5] =  43.7037
        to_missing.iloc[row.Index, 6] =  -79.4524
    elif to_missing.iloc[row.Index, 0] == "Forest Hill South" :
        to_missing.iloc[row.Index, 5] =  43.6932
        to_missing.iloc[row.Index, 6] =  -79.4126
    elif to_missing.iloc[row.Index, 0] == "Glenfield-Jane Heights" :
        to_missing.iloc[row.Index, 5] =  43.757222
        to_missing.iloc[row.Index, 6] =  -79.517778
    elif to_missing.iloc[row.Index, 0] == "Junction Area" :
        to_missing.iloc[row.Index, 5] =  43.665556
        to_missing.iloc[row.Index, 6] =  -79.464444
    elif to_missing.iloc[row.Index, 0] == "Kennedy Park" :
        to_missing.iloc[row.Index, 5] =  43.716667
        to_missing.iloc[row.Index, 6] =  -79.259722
    elif to_missing.iloc[row.Index, 0] == "Kingsway South" :
        to_missing.iloc[row.Index, 5] =  43.6527
        to_missing.iloc[row.Index, 6] =  -79.5072
    elif to_missing.iloc[row.Index, 0] == "Lambton Baby Point" :
        to_missing.iloc[row.Index, 5] =  43.6575
        to_missing.iloc[row.Index, 6] =  -79.4925
    elif to_missing.iloc[row.Index, 0] == "Malvern" :
        to_missing.iloc[row.Index, 5] =  43.811667
        to_missing.iloc[row.Index, 6] =  -79.231111
    elif to_missing.iloc[row.Index, 0] == "Markland Wood" :
        to_missing.iloc[row.Index, 5] =  43.6336
        to_missing.iloc[row.Index, 6] =  -79.5708
    elif to_missing.iloc[row.Index, 0] == "Milliken" :
        to_missing.iloc[row.Index, 5] =  43.825833
        to_missing.iloc[row.Index, 6] =  -79.300833
    elif to_missing.iloc[row.Index, 0] == "Morningside" :
        to_missing.iloc[row.Index, 5] =  43.787
        to_missing.iloc[row.Index, 6] =  -79.206
    elif to_missing.iloc[row.Index, 0] == "Roncesvalles" :
        to_missing.iloc[row.Index, 5] =  43.6463
        to_missing.iloc[row.Index, 6] =  -79.4491
    elif to_missing.iloc[row.Index, 0] == "Rouge" :
        to_missing.iloc[row.Index, 5] =  43.820833
        to_missing.iloc[row.Index, 6] =  -79.206111
    elif to_missing.iloc[row.Index, 0] == "Rustic" :
        to_missing.iloc[row.Index, 5] =  43.713
        to_missing.iloc[row.Index, 6] =  -79.489
    elif to_missing.iloc[row.Index, 0] == "South Parkdale" :
        to_missing.iloc[row.Index, 5] =  43.640454
        to_missing.iloc[row.Index, 6] =  -79.436731
    elif to_missing.iloc[row.Index, 0] == "South Riverdale" :
        to_missing.iloc[row.Index, 5] =  43.66775
        to_missing.iloc[row.Index, 6] =  -79.34961
    elif to_missing.iloc[row.Index, 0] == "Stonegate-Queensway" :
        to_missing.iloc[row.Index, 5] =  43.630278
        to_missing.iloc[row.Index, 6] =  -79.484167
    elif to_missing.iloc[row.Index, 0] == "University" :
        to_missing.iloc[row.Index, 5] =  43.661667
        to_missing.iloc[row.Index, 6] =  -79.395
    elif to_missing.iloc[row.Index, 0] == "Waterfront Communities-The Island" :
        to_missing.iloc[row.Index, 5] =  43.620833
        to_missing.iloc[row.Index, 6] =  -79.378611
    elif to_missing.iloc[row.Index, 0] == "West Humber-Clairville" :
        to_missing.iloc[row.Index, 5] =  43.742
        to_missing.iloc[row.Index, 6] =  -79.617
    elif to_missing.iloc[row.Index, 0] == "Weston" :
        to_missing.iloc[row.Index, 5] =  43.700989
        to_missing.iloc[row.Index, 6] =  -79.5197
    elif to_missing.iloc[row.Index, 0] == "Wychwood" :
        to_missing.iloc[row.Index, 5] =  43.68
        to_missing.iloc[row.Index, 6] =  -79.423611       
    elif to_missing.iloc[row.Index, 0] == 'Blake-Jones' :
        to_missing.iloc[row.Index, 5] =  43.66775
        to_missing.iloc[row.Index, 6] =  -79.34961
    elif to_missing.iloc[row.Index, 0] == 'Clanton Park' :
        to_missing.iloc[row.Index, 5] =  43.75
        to_missing.iloc[row.Index, 6] =  -79.45
    elif to_missing.iloc[row.Index, 0] == 'Mount Pleasant East' :
        to_missing.iloc[row.Index, 5] =  43.696351
        to_missing.iloc[row.Index, 6] =  -79.384882
    elif to_missing.iloc[row.Index, 0] == 'Mount Pleasant West' :
        to_missing.iloc[row.Index, 5] =  43.696351
        to_missing.iloc[row.Index, 6] =  -79.384882
    elif to_missing.iloc[row.Index, 0] == 'North Riverdale' :
        to_missing.iloc[row.Index, 5] =  43.66775
        to_missing.iloc[row.Index, 6] =  -79.34961
    elif to_missing.iloc[row.Index, 0] == 'Oakwood Village' :
        to_missing.iloc[row.Index, 5] =  43.6925
        to_missing.iloc[row.Index, 6] =  -79.440833
    elif to_missing.iloc[row.Index, 0] == 'Danforth' :
        to_missing.iloc[row.Index, 5] =  43.68
        to_missing.iloc[row.Index, 6] =   -79.349
    elif to_missing.iloc[row.Index, 0] == 'Kensington-Chinatown' :
        to_missing.iloc[row.Index, 5] =  43.6529
        to_missing.iloc[row.Index, 6] =  -79.3980
    elif to_missing.iloc[row.Index, 0] == 'Woburn' :
        to_missing.iloc[row.Index, 5] =  43.766667
        to_missing.iloc[row.Index, 6] =  -79.227778
    elif to_missing.iloc[row.Index, 0] == 'Weston-Pelham Park' :
        to_missing.iloc[row.Index, 5] =  43.672
        to_missing.iloc[row.Index, 6] =  -79.457
    elif to_missing.iloc[row.Index, 0] == 'Mount Pleasant West' :
        to_missing.iloc[row.Index, 5] =  43.672
        to_missing.iloc[row.Index, 6] =  -79.457
    elif to_missing.iloc[row.Index, 0] == 'Lawrence Park South' :
        to_missing.iloc[row.Index, 5] =  43.722
        to_missing.iloc[row.Index, 6] =  -79.388
    elif to_missing.iloc[row.Index, 0] == 'York University Heights' :
        to_missing.iloc[row.Index, 5] =  43.762
        to_missing.iloc[row.Index, 6] =  -79.5
    elif to_missing.iloc[row.Index, 0] == 'Long Branch' :
        to_missing.iloc[row.Index, 5] =  43.762
        to_missing.iloc[row.Index, 6] =  -79.5
    elif to_missing.iloc[row.Index, 0] == 'Lawrence Park North' :
        to_missing.iloc[row.Index, 5] =  43.722
        to_missing.iloc[row.Index, 6] =  -79.388
    elif to_missing.iloc[row.Index, 0] == 'Lansing-Westgate' :
        to_missing.iloc[row.Index, 5] =  43.757
        to_missing.iloc[row.Index, 6] =  -79.417
    elif to_missing.iloc[row.Index, 0] == 'Forest Hill North' :
        to_missing.iloc[row.Index, 5] =  43.7
        to_missing.iloc[row.Index, 6] =  -79.416667
    elif to_missing.iloc[row.Index, 0] == 'Niagara' :
        to_missing.iloc[row.Index, 5] =  43.643
        to_missing.iloc[row.Index, 6] =  -79.408
    elif to_missing.iloc[row.Index, 0] == 'Caledonia-Fairbank' :
        to_missing.iloc[row.Index, 5] =  43.6899
        to_missing.iloc[row.Index, 6] =  -79.4552
    elif to_missing.iloc[row.Index, 0] == 'Kingsview Village-The Westway' :
        to_missing.iloc[row.Index, 5] =  43.699
        to_missing.iloc[row.Index, 6] =  -79.5479
    elif to_missing.iloc[row.Index, 0] == 'Pelmo Park-Humberlea' :
        to_missing.iloc[row.Index, 5] =  43.7213
        to_missing.iloc[row.Index, 6] =  -79.5332
    elif to_missing.iloc[row.Index, 0] == 'Woodbine Corridor' :
        to_missing.iloc[row.Index, 5] =  43.682088
        to_missing.iloc[row.Index, 6] =  -79.303272
    elif to_missing.iloc[row.Index, 0] == 'Woodbine-Lumsden' :
        to_missing.iloc[row.Index, 5] =  43.6922
        to_missing.iloc[row.Index, 6] =  -79.3099
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %% [markdown]
# ####Now, when all coordinates are obtained, we can concatenate the two dataframes into "to_final"

# %%
frames = [to_selected, to_missing]
to_final = pd.concat(frames)
to_final.reset_index(inplace=True)
del to_final["index"]
del to_final["gcode"]
del to_final["full_address"]
print(to_final.shape)
to_final.head()
# Out:
# (140, 7)
# 0                  Neighborhood  +/- Population(%)  Population/sqkm  \
# 0               Agincourt North                 -3             3929
# 1  Agincourt South-Malvern West                  8             3034
# 2                     Alderwood                  1             2435
# 3                         Annex                  4            10863
# 4             Banbury-Don Mills                  2             2775
#
# 0  Average income ($}  French speaking (%) Latitude Longitude
# 0               30414             4.293615   43.808  -79.2664
# 1               31825             4.482889   43.782  -79.2577
# 2               47709             7.383441  43.6017  -79.5452
# 3              112766            19.737273  43.6703  -79.4071
# 4               67757            10.525366  43.7527  -79.3653

# %% [markdown]
# ###3. Adding total crime rates per neighborhood from the Toronto Police:

# %%
crimes=get_crime_rates()  #using the function we defined in the beginning
crimes.head()
# Out:
#               Neighborhood  Assault rate  Autotheft rate  Breakandenter rate  \
# 0           Yonge-St.Clair         295.3            47.9               223.5
# 1  York University Heights        1340.9           521.9               391.4
# 2         Lansing-Westgate         445.4           198.0               241.3
# 3       Yorkdale-Glen Park        1411.8           412.1               567.4
# 4      Stonegate-Queensway         327.3           135.7               255.5
#
#   Homicide rate  Robbery rate  Theftover rate  Total crime rate
# 0             0          31.9            47.9             646.5
# 1             0         286.3           101.5            2642.0
# 2             0          68.1            68.1            1020.9
# 3           6.8         283.7           195.9            2870.9
# 4             0          87.8            16.0             822.3

# %% [markdown]
# ####Do the datasets have matching neighborhood names? Let's find out which one, if any, are dissimilar:

# %%
# Sorting both df on Neighborhood
crimes.sort_values("Neighborhood", inplace=True)
crimes.reset_index(inplace=True)
del crimes["index"]

to_final.sort_values("Neighborhood", inplace=True)
to_final.reset_index(inplace=True)
del to_final["index"]

# To compare Neighborhood names, let's make a new df and add a column with boolean values to call whether names are similar or not 
column_names=["crimes_n","to_final_n"]
compare_neigh = pd.DataFrame(columns=column_names)
compare_neigh["crimes_n"]=crimes["Neighborhood"]
compare_neigh["to_final_n"]=to_final["Neighborhood"]
compare_neigh["Match"]=compare_neigh["to_final_n"].where(compare_neigh["to_final_n"].values==compare_neigh["crimes_n"].values).notna()
compare_miss = compare_neigh[compare_neigh.to_final_n != compare_neigh["crimes_n"]]
compare_miss
# Out:
#                             crimes_n                           to_final_n  \
# 19   Cabbagetown-South St.James Town     Cabbagetown-South St. James Town
# 77                            Mimico  Mimico (includes Humber Bay Shores)
# 89               North St.James Town                 North St. James Town
# 127               Weston-Pellam Park                   Weston-Pelham Park
#
#      Match
# 19   False
# 77   False
# 89   False
# 127  False

# %% [markdown]
# ####As can be seen, four Neighborhoods are not identically named. But they only differ due to minor spelling differences. Let's therefore merge the two datasets based on the neighborhood list in to_final

# %%
crimes["to_final neighs"] = to_final["Neighborhood"]

#Let's drop all columns but the total criminal rate and neighborhoods from crimes
crimes=crimes[["to_final neighs", "Total crime rate"]]

#Now we can merge the datasets
to_final = to_final.merge(crimes, left_on="Neighborhood", right_on="to_final neighs")
del to_final["to_final neighs"]

#Let's verify its shape and columns
print(to_final.shape)
to_final.head()
# Out:
# (140, 8)
#                    Neighborhood  +/- Population(%)  Population/sqkm  \
# 0               Agincourt North                 -3             3929
# 1  Agincourt South-Malvern West                  8             3034
# 2                     Alderwood                  1             2435
# 3                         Annex                  4            10863
# 4             Banbury-Don Mills                  2             2775
#
#    Average income ($}  French speaking (%) Latitude Longitude  \
# 0               30414             4.293615   43.808  -79.2664
# 1               31825             4.482889   43.782  -79.2577
# 2               47709             7.383441  43.6017  -79.5452
# 3              112766            19.737273  43.6703  -79.4071
# 4               67757            10.525366  43.7527  -79.3653
#
#    Total crime rate
# 0             735.2
# 1            1384.8
# 2             730.1
# 3            1975.5
# 4             798.1

# %% [markdown]
# ##3. Adding Foursquare restaurant data

# %% [markdown]
# ####Let's use the obtained coordinates in our dataframe to find nearby venues:

# %%
toronto_venues=getNearbyVenues(names=to_final["Neighborhood"], latitudes=to_final["Latitude"],longitudes=to_final["Longitude"])
toronto_venues.head()
# Out:
# Agincourt North
# Agincourt South-Malvern West
# Alderwood
# Annex
# Banbury-Don Mills
# Bathurst Manor
# Bay Street Corridor
# Bayview Village
# Bayview Woods-Steeles
# Bedford Park-Nortown
# Beechborough-Greenbrook
# Bendale
# Birchcliffe-Cliffside
# Black Creek
# Blake-Jones
# Briar Hill-Belgravia
# Bridle Path-Sunnybrook-York Mills
# Broadview North
# Brookhaven-Amesbury
# Cabbagetown-South St. James Town
# Caledonia-Fairbank
# Casa Loma
# Centennial Scarborough
# Church-Yonge Corridor
# Clairlea-Birchmount
# Clanton Park
# Cliffcrest
# Corso Italia-Davenport
# Danforth
# Danforth East York
# Don Valley Village
# Dorset Park
# Dovercourt-Wallace Emerson-Junction
# Downsview-Roding-CFB
# Dufferin Grove
# East End-Danforth
# Edenbridge-Humber Valley
# Eglinton East
# Elms-Old Rexdale
# Englemount-Lawrence
# Eringate-Centennial-West Deane
# Etobicoke West Mall
# Flemingdon Park
# Forest Hill North
# Forest Hill South
# Glenfield-Jane Heights
# Greenwood-Coxwell
# Guildwood
# Henry Farm
# High Park North
# High Park-Swansea
# Highland Creek
# Hillcrest Village
# Humber Heights-Westmount
# Humber Summit
# Humbermede
# Humewood-Cedarvale
# Ionview
# Islington-City Centre West
# Junction Area
# Keelesdale-Eglinton West
# Kennedy Park
# Kensington-Chinatown
# Kingsview Village-The Westway
# Kingsway South
# L'Amoreaux
# Lambton Baby Point
# Lansing-Westgate
# Lawrence Park North
# Lawrence Park South
# Leaside-Bennington
# Little Portugal
# Long Branch
# Malvern
# Maple Leaf
# Markland Wood
# Milliken
# Mimico (includes Humber Bay Shores)
# Morningside
# Moss Park
# Mount Dennis
# Mount Olive-Silverstone-Jamestown
# Mount Pleasant East
# Mount Pleasant West
# New Toronto
# Newtonbrook East
# Newtonbrook West
# Niagara
# North Riverdale
# North St. James Town
# O'Connor-Parkview
# Oakridge
# Oakwood Village
# Old East York
# Palmerston-Little Italy
# Parkwoods-Donalda
# Pelmo Park-Humberlea
# Playter Estates-Danforth
# Pleasant View
# Princess-Rosethorn
# Regent Park
# Rexdale-Kipling
# Rockcliffe-Smythe
# Roncesvalles
# Rosedale-Moore Park
# Rouge
# Runnymede-Bloor West Village
# Rustic
# Scarborough Village
# South Parkdale
# South Riverdale
# St.Andrew-Windfields
# Steeles
# Stonegate-Queensway
# Tam O'Shanter-Sullivan
# Taylor-Massey
# The Beaches
# Thistletown-Beaumond Heights
# Thorncliffe Park
# Trinity-Bellwoods
# University
# Victoria Village
# Waterfront Communities-The Island
# West Hill
# West Humber-Clairville
# Westminster-Branson
# Weston
# Weston-Pelham Park
# Wexford/Maryvale
# Willowdale East
# Willowdale West
# Willowridge-Martingrove-Richview
# Woburn
# Woodbine Corridor
# Woodbine-Lumsden
# Wychwood
# Yonge-Eglinton
# Yonge-St.Clair
# York University Heights
# Yorkdale-Glen Park

# %%
toronto_venues.groupby('Neighborhood').count()
# Out:
#                                      Neighborhood Latitude  \
# Neighborhood
# Agincourt North                                         24
# Agincourt South-Malvern West                            67
# Alderwood                                               24
# Annex                                                  100
# Banbury-Don Mills                                       27
# Bathurst Manor                                          19
# Bay Street Corridor                                     78
# Bayview Village                                         49
# Bayview Woods-Steeles                                   11
# Bedford Park-Nortown                                    50
# Beechborough-Greenbrook                                 16
# Bendale                                                 20
# Birchcliffe-Cliffside                                   17
# Black Creek                                              6
# Blake-Jones                                             97
# Briar Hill-Belgravia                                    37
# Bridle Path-Sunnybrook-York Mills                        5
# Broadview North                                         92
# Brookhaven-Amesbury                                     15
# Cabbagetown-South St. James Town                        62
# Caledonia-Fairbank                                      23
# Casa Loma                                               77
# Centennial Scarborough                                   7
# Church-Yonge Corridor                                  100
# Clairlea-Birchmount                                     28
# Clanton Park                                            11
# Cliffcrest                                              13
# Corso Italia-Davenport                                  54
# Danforth                                                61
# Danforth East York                                      56
# Don Valley Village                                      38
# Dorset Park                                             26
# Dovercourt-Wallace Emerson-Junction                    100
# Downsview-Roding-CFB                                     4
# Dufferin Grove                                         100
# East End-Danforth                                      100
# Edenbridge-Humber Valley                                13
# Eglinton East                                           11
# Elms-Old Rexdale                                         9
# Englemount-Lawrence                                     24
# Eringate-Centennial-West Deane                          19
# Etobicoke West Mall                                     29
# Flemingdon Park                                         34
# Forest Hill North                                       28
# Forest Hill South                                       28
# Glenfield-Jane Heights                                  97
# Greenwood-Coxwell                                       62
# Guildwood                                               13
# Henry Farm                                              16
# High Park North                                         92
# High Park-Swansea                                       73
# Highland Creek                                           5
# Hillcrest Village                                       74
# Humber Heights-Westmount                                21
# Humber Summit                                            4
# Humbermede                                              22
# Humewood-Cedarvale                                      67
# Ionview                                                 20
# Islington-City Centre West                              47
# Junction Area                                           89
# Keelesdale-Eglinton West                                19
# Kennedy Park                                            11
# Kensington-Chinatown                                   100
# Kingsview Village-The Westway                           17
# Kingsway South                                          50
# L'Amoreaux                                              26
# Lambton Baby Point                                      26
# Lansing-Westgate                                        23
# Lawrence Park North                                     54
# Lawrence Park South                                     54
# Leaside-Bennington                                      48
# Little Portugal                                        100
# Long Branch                                             26
# Malvern                                                 17
# Maple Leaf                                              13
# Markland Wood                                           11
# Milliken                                                55
# Mimico (includes Humber Bay Shores)                     25
# Morningside                                             14
# Moss Park                                              100
# Mount Dennis                                            14
# Mount Olive-Silverstone-Jamestown                       12
# Mount Pleasant East                                     43
# Mount Pleasant West                                     43
# New Toronto                                             20
# Newtonbrook East                                        60
# Newtonbrook West                                        60
# Niagara                                                100
# North Riverdale                                        100
# North St. James Town                                   100
# O'Connor-Parkview                                       25
# Oakridge                                                 7
# Oakwood Village                                         62
# Old East York                                           28
# Palmerston-Little Italy                                100
# Parkwoods-Donalda                                       31
# Pelmo Park-Humberlea                                    10
# Playter Estates-Danforth                               100
# Pleasant View                                           19
# Princess-Rosethorn                                       6
# Regent Park                                            100
# Rexdale-Kipling                                          9
# Rockcliffe-Smythe                                       22
# Roncesvalles                                           100
# Rosedale-Moore Park                                     66
# Rouge                                                   10
# Runnymede-Bloor West Village                            76
# Rustic                                                  16
# Scarborough Village                                     18
# South Parkdale                                          80
# South Riverdale                                        100
# St.Andrew-Windfields                                   100
# Steeles                                                 29
# Stonegate-Queensway                                     52
# Tam O'Shanter-Sullivan                                  40
# Taylor-Massey                                           18
# The Beaches                                             90
# Thistletown-Beaumond Heights                            17
# Thorncliffe Park                                        26
# Trinity-Bellwoods                                      100
# University                                             100
# Victoria Village                                        14
# Waterfront Communities-The Island                       30
# West Hill                                               36
# West Humber-Clairville                                  24
# Westminster-Branson                                     30
# Weston                                                  16
# Weston-Pelham Park                                      71
# Wexford/Maryvale                                        34
# Willowdale East                                         93
# Willowdale West                                         93
# Willowridge-Martingrove-Richview                         8
# Woburn                                                  40
# Woodbine Corridor                                       52
# Woodbine-Lumsden                                        45
# Wychwood                                                71
# Yonge-Eglinton                                         100
# Yonge-St.Clair                                          46
# York University Heights                                 30
# Yorkdale-Glen Park                                      38
#
#                                      Neighborhood Longitude  Venue   id  \
# Neighborhood
# Agincourt North                                          24     24   24
# Agincourt South-Malvern West                             67     67   67
# Alderwood                                                24     24   24
# Annex                                                   100    100  100
# Banbury-Don Mills                                        27     27   27
# Bathurst Manor                                           19     19   19
# Bay Street Corridor                                      78     78   78
# Bayview Village                                          49     49   49
# Bayview Woods-Steeles                                    11     11   11
# Bedford Park-Nortown                                     50     50   50
# Beechborough-Greenbrook                                  16     16   16
# Bendale                                                  20     20   20
# Birchcliffe-Cliffside                                    17     17   17
# Black Creek                                               6      6    6
# Blake-Jones                                              97     97   97
# Briar Hill-Belgravia                                     37     37   37
# Bridle Path-Sunnybrook-York Mills                         5      5    5
# Broadview North                                          92     92   92
# Brookhaven-Amesbury                                      15     15   15
# Cabbagetown-South St. James Town                         62     62   62
# Caledonia-Fairbank                                       23     23   23
# Casa Loma                                                77     77   77
# Centennial Scarborough                                    7      7    7
# Church-Yonge Corridor                                   100    100  100
# Clairlea-Birchmount                                      28     28   28
# Clanton Park                                             11     11   11
# Cliffcrest                                               13     13   13
# Corso Italia-Davenport                                   54     54   54
# Danforth                                                 61     61   61
# Danforth East York                                       56     56   56
# Don Valley Village                                       38     38   38
# Dorset Park                                              26     26   26
# Dovercourt-Wallace Emerson-Junction                     100    100  100
# Downsview-Roding-CFB                                      4      4    4
# Dufferin Grove                                          100    100  100
# East End-Danforth                                       100    100  100
# Edenbridge-Humber Valley                                 13     13   13
# Eglinton East                                            11     11   11
# Elms-Old Rexdale                                          9      9    9
# Englemount-Lawrence                                      24     24   24
# Eringate-Centennial-West Deane                           19     19   19
# Etobicoke West Mall                                      29     29   29
# Flemingdon Park                                          34     34   34
# Forest Hill North                                        28     28   28
# Forest Hill South                                        28     28   28
# Glenfield-Jane Heights                                   97     97   97
# Greenwood-Coxwell                                        62     62   62
# Guildwood                                                13     13   13
# Henry Farm                                               16     16   16
# High Park North                                          92     92   92
# High Park-Swansea                                        73     73   73
# Highland Creek                                            5      5    5
# Hillcrest Village                                        74     74   74
# Humber Heights-Westmount                                 21     21   21
# Humber Summit                                             4      4    4
# Humbermede                                               22     22   22
# Humewood-Cedarvale                                       67     67   67
# Ionview                                                  20     20   20
# Islington-City Centre West                               47     47   47
# Junction Area                                            89     89   89
# Keelesdale-Eglinton West                                 19     19   19
# Kennedy Park                                             11     11   11
# Kensington-Chinatown                                    100    100  100
# Kingsview Village-The Westway                            17     17   17
# Kingsway South                                           50     50   50
# L'Amoreaux                                               26     26   26
# Lambton Baby Point                                       26     26   26
# Lansing-Westgate                                         23     23   23
# Lawrence Park North                                      54     54   54
# Lawrence Park South                                      54     54   54
# Leaside-Bennington                                       48     48   48
# Little Portugal                                         100    100  100
# Long Branch                                              26     26   26
# Malvern                                                  17     17   17
# Maple Leaf                                               13     13   13
# Markland Wood                                            11     11   11
# Milliken                                                 55     55   55
# Mimico (includes Humber Bay Shores)                      25     25   25
# Morningside                                              14     14   14
# Moss Park                                               100    100  100
# Mount Dennis                                             14     14   14
# Mount Olive-Silverstone-Jamestown                        12     12   12
# Mount Pleasant East                                      43     43   43
# Mount Pleasant West                                      43     43   43
# New Toronto                                              20     20   20
# Newtonbrook East                                         60     60   60
# Newtonbrook West                                         60     60   60
# Niagara                                                 100    100  100
# North Riverdale                                         100    100  100
# North St. James Town                                    100    100  100
# O'Connor-Parkview                                        25     25   25
# Oakridge                                                  7      7    7
# Oakwood Village                                          62     62   62
# Old East York                                            28     28   28
# Palmerston-Little Italy                                 100    100  100
# Parkwoods-Donalda                                        31     31   31
# Pelmo Park-Humberlea                                     10     10   10
# Playter Estates-Danforth                                100    100  100
# Pleasant View                                            19     19   19
# Princess-Rosethorn                                        6      6    6
# Regent Park                                             100    100  100
# Rexdale-Kipling                                           9      9    9
# Rockcliffe-Smythe                                        22     22   22
# Roncesvalles                                            100    100  100
# Rosedale-Moore Park                                      66     66   66
# Rouge                                                    10     10   10
# Runnymede-Bloor West Village                             76     76   76
# Rustic                                                   16     16   16
# Scarborough Village                                      18     18   18
# South Parkdale                                           80     80   80
# South Riverdale                                         100    100  100
# St.Andrew-Windfields                                    100    100  100
# Steeles                                                  29     29   29
# Stonegate-Queensway                                      52     52   52
# Tam O'Shanter-Sullivan                                   40     40   40
# Taylor-Massey                                            18     18   18
# The Beaches                                              90     90   90
# Thistletown-Beaumond Heights                             17     17   17
# Thorncliffe Park                                         26     26   26
# Trinity-Bellwoods                                       100    100  100
# University                                              100    100  100
# Victoria Village                                         14     14   14
# Waterfront Communities-The Island                        30     30   30
# West Hill                                                36     36   36
# West Humber-Clairville                                   24     24   24
# Westminster-Branson                                      30     30   30
# Weston                                                   16     16   16
# Weston-Pelham Park                                       71     71   71
# Wexford/Maryvale                                         34     34   34
# Willowdale East                                          93     93   93
# Willowdale West                                          93     93   93
# Willowridge-Martingrove-Richview                          8      8    8
# Woburn                                                   40     40   40
# Woodbine Corridor                                        52     52   52
# Woodbine-Lumsden                                         45     45   45
# Wychwood                                                 71     71   71
# Yonge-Eglinton                                          100    100  100
# Yonge-St.Clair                                           46     46   46
# York University Heights                                  30     30   30
# Yorkdale-Glen Park                                       38     38   38
#
#                                      Venue Latitude  Venue Longitude  \
# Neighborhood
# Agincourt North                                  24               24
# Agincourt South-Malvern West                     67               67
# Alderwood                                        24               24
# Annex                                           100              100
# Banbury-Don Mills                                27               27
# Bathurst Manor                                   19               19
# Bay Street Corridor                              78               78
# Bayview Village                                  49               49
# Bayview Woods-Steeles                            11               11
# Bedford Park-Nortown                             50               50
# Beechborough-Greenbrook                          16               16
# Bendale                                          20               20
# Birchcliffe-Cliffside                            17               17
# Black Creek                                       6                6
# Blake-Jones                                      97               97
# Briar Hill-Belgravia                             37               37
# Bridle Path-Sunnybrook-York Mills                 5                5
# Broadview North                                  92               92
# Brookhaven-Amesbury                              15               15
# Cabbagetown-South St. James Town                 62               62
# Caledonia-Fairbank                               23               23
# Casa Loma                                        77               77
# Centennial Scarborough                            7                7
# Church-Yonge Corridor                           100              100
# Clairlea-Birchmount                              28               28
# Clanton Park                                     11               11
# Cliffcrest                                       13               13
# Corso Italia-Davenport                           54               54
# Danforth                                         61               61
# Danforth East York                               56               56
# Don Valley Village                               38               38
# Dorset Park                                      26               26
# Dovercourt-Wallace Emerson-Junction             100              100
# Downsview-Roding-CFB                              4                4
# Dufferin Grove                                  100              100
# East End-Danforth                               100              100
# Edenbridge-Humber Valley                         13               13
# Eglinton East                                    11               11
# Elms-Old Rexdale                                  9                9
# Englemount-Lawrence                              24               24
# Eringate-Centennial-West Deane                   19               19
# Etobicoke West Mall                              29               29
# Flemingdon Park                                  34               34
# Forest Hill North                                28               28
# Forest Hill South                                28               28
# Glenfield-Jane Heights                           97               97
# Greenwood-Coxwell                                62               62
# Guildwood                                        13               13
# Henry Farm                                       16               16
# High Park North                                  92               92
# High Park-Swansea                                73               73
# Highland Creek                                    5                5
# Hillcrest Village                                74               74
# Humber Heights-Westmount                         21               21
# Humber Summit                                     4                4
# Humbermede                                       22               22
# Humewood-Cedarvale                               67               67
# Ionview                                          20               20
# Islington-City Centre West                       47               47
# Junction Area                                    89               89
# Keelesdale-Eglinton West                         19               19
# Kennedy Park                                     11               11
# Kensington-Chinatown                            100              100
# Kingsview Village-The Westway                    17               17
# Kingsway South                                   50               50
# L'Amoreaux                                       26               26
# Lambton Baby Point                               26               26
# Lansing-Westgate                                 23               23
# Lawrence Park North                              54               54
# Lawrence Park South                              54               54
# Leaside-Bennington                               48               48
# Little Portugal                                 100              100
# Long Branch                                      26               26
# Malvern                                          17               17
# Maple Leaf                                       13               13
# Markland Wood                                    11               11
# Milliken                                         55               55
# Mimico (includes Humber Bay Shores)              25               25
# Morningside                                      14               14
# Moss Park                                       100              100
# Mount Dennis                                     14               14
# Mount Olive-Silverstone-Jamestown                12               12
# Mount Pleasant East                              43               43
# Mount Pleasant West                              43               43
# New Toronto                                      20               20
# Newtonbrook East                                 60               60
# Newtonbrook West                                 60               60
# Niagara                                         100              100
# North Riverdale                                 100              100
# North St. James Town                            100              100
# O'Connor-Parkview                                25               25
# Oakridge                                          7                7
# Oakwood Village                                  62               62
# Old East York                                    28               28
# Palmerston-Little Italy                         100              100
# Parkwoods-Donalda                                31               31
# Pelmo Park-Humberlea                             10               10
# Playter Estates-Danforth                        100              100
# Pleasant View                                    19               19
# Princess-Rosethorn                                6                6
# Regent Park                                     100              100
# Rexdale-Kipling                                   9                9
# Rockcliffe-Smythe                                22               22
# Roncesvalles                                    100              100
# Rosedale-Moore Park                              66               66
# Rouge                                            10               10
# Runnymede-Bloor West Village                     76               76
# Rustic                                           16               16
# Scarborough Village                              18               18
# South Parkdale                                   80               80
# South Riverdale                                 100              100
# St.Andrew-Windfields                            100              100
# Steeles                                          29               29
# Stonegate-Queensway                              52               52
# Tam O'Shanter-Sullivan                           40               40
# Taylor-Massey                                    18               18
# The Beaches                                      90               90
# Thistletown-Beaumond Heights                     17               17
# Thorncliffe Park                                 26               26
# Trinity-Bellwoods                               100              100
# University                                      100              100
# Victoria Village                                 14               14
# Waterfront Communities-The Island                30               30
# West Hill                                        36               36
# West Humber-Clairville                           24               24
# Westminster-Branson                              30               30
# Weston                                           16               16
# Weston-Pelham Park                               71               71
# Wexford/Maryvale                                 34               34
# Willowdale East                                  93               93
# Willowdale West                                  93               93
# Willowridge-Martingrove-Richview                  8                8
# Woburn                                           40               40
# Woodbine Corridor                                52               52
# Woodbine-Lumsden                                 45               45
# Wychwood                                         71               71
# Yonge-Eglinton                                  100              100
# Yonge-St.Clair                                   46               46
# York University Heights                          30               30
# Yorkdale-Glen Park                               38               38
#
#                                      Venue Category
# Neighborhood
# Agincourt North                                  24
# Agincourt South-Malvern West                     67
# Alderwood                                        24
# Annex                                           100
# Banbury-Don Mills                                27
# Bathurst Manor                                   19
# Bay Street Corridor                              78
# Bayview Village                                  49
# Bayview Woods-Steeles                            11
# Bedford Park-Nortown                             50
# Beechborough-Greenbrook                          16
# Bendale                                          20
# Birchcliffe-Cliffside                            17
# Black Creek                                       6
# Blake-Jones                                      97
# Briar Hill-Belgravia                             37
# Bridle Path-Sunnybrook-York Mills                 5
# Broadview North                                  92
# Brookhaven-Amesbury                              15
# Cabbagetown-South St. James Town                 62
# Caledonia-Fairbank                               23
# Casa Loma                                        77
# Centennial Scarborough                            7
# Church-Yonge Corridor                           100
# Clairlea-Birchmount                              28
# Clanton Park                                     11
# Cliffcrest                                       13
# Corso Italia-Davenport                           54
# Danforth                                         61
# Danforth East York                               56
# Don Valley Village                               38
# Dorset Park                                      26
# Dovercourt-Wallace Emerson-Junction             100
# Downsview-Roding-CFB                              4
# Dufferin Grove                                  100
# East End-Danforth                               100
# Edenbridge-Humber Valley                         13
# Eglinton East                                    11
# Elms-Old Rexdale                                  9
# Englemount-Lawrence                              24
# Eringate-Centennial-West Deane                   19
# Etobicoke West Mall                              29
# Flemingdon Park                                  34
# Forest Hill North                                28
# Forest Hill South                                28
# Glenfield-Jane Heights                           97
# Greenwood-Coxwell                                62
# Guildwood                                        13
# Henry Farm                                       16
# High Park North                                  92
# High Park-Swansea                                73
# Highland Creek                                    5
# Hillcrest Village                                74
# Humber Heights-Westmount                         21
# Humber Summit                                     4
# Humbermede                                       22
# Humewood-Cedarvale                               67
# Ionview                                          20
# Islington-City Centre West                       47
# Junction Area                                    89
# Keelesdale-Eglinton West                         19
# Kennedy Park                                     11
# Kensington-Chinatown                            100
# Kingsview Village-The Westway                    17
# Kingsway South                                   50
# L'Amoreaux                                       26
# Lambton Baby Point                               26
# Lansing-Westgate                                 23
# Lawrence Park North                              54
# Lawrence Park South                              54
# Leaside-Bennington                               48
# Little Portugal                                 100
# Long Branch                                      26
# Malvern                                          17
# Maple Leaf                                       13
# Markland Wood                                    11
# Milliken                                         55
# Mimico (includes Humber Bay Shores)              25
# Morningside                                      14
# Moss Park                                       100
# Mount Dennis                                     14
# Mount Olive-Silverstone-Jamestown                12
# Mount Pleasant East                              43
# Mount Pleasant West                              43
# New Toronto                                      20
# Newtonbrook East                                 60
# Newtonbrook West                                 60
# Niagara                                         100
# North Riverdale                                 100
# North St. James Town                            100
# O'Connor-Parkview                                25
# Oakridge                                          7
# Oakwood Village                                  62
# Old East York                                    28
# Palmerston-Little Italy                         100
# Parkwoods-Donalda                                31
# Pelmo Park-Humberlea                             10
# Playter Estates-Danforth                        100
# Pleasant View                                    19
# Princess-Rosethorn                                6
# Regent Park                                     100
# Rexdale-Kipling                                   9
# Rockcliffe-Smythe                                22
# Roncesvalles                                    100
# Rosedale-Moore Park                              66
# Rouge                                            10
# Runnymede-Bloor West Village                     76
# Rustic                                           16
# Scarborough Village                              18
# South Parkdale                                   80
# South Riverdale                                 100
# St.Andrew-Windfields                            100
# Steeles                                          29
# Stonegate-Queensway                              52
# Tam O'Shanter-Sullivan                           40
# Taylor-Massey                                    18
# The Beaches                                      90
# Thistletown-Beaumond Heights                     17
# Thorncliffe Park                                 26
# Trinity-Bellwoods                               100
# University                                      100
# Victoria Village                                 14
# Waterfront Communities-The Island                30
# West Hill                                        36
# West Humber-Clairville                           24
# Westminster-Branson                              30
# Weston                                           16
# Weston-Pelham Park                               71
# Wexford/Maryvale                                 34
# Willowdale East                                  93
# Willowdale West                                  93
# Willowridge-Martingrove-Richview                  8
# Woburn                                           40
# Woodbine Corridor                                52
# Woodbine-Lumsden                                 45
# Wychwood                                         71
# Yonge-Eglinton                                  100
# Yonge-St.Clair                                   46
# York University Heights                          30
# Yorkdale-Glen Park                               38

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 340 uniques categories.

# %% [markdown]
# #### Let's convert venues to dummies to be able to quantify them per neighborhood
# ####-I decided to only pull out venues that are either Restaurants or French Restaurants:

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

# calculating the sum for each neighborhood
toronto_grouped = toronto_onehot.groupby('Neighborhood').sum().reset_index()

# creating a french restaurant df:
res_freq = toronto_grouped[["Neighborhood", "French Restaurant"]]

# Adding total restaurant frequency to rest_freq:
restaurants = toronto_grouped.filter(regex='Restaurant')
res_freq['Restaurant Total freq'] = restaurants.sum(axis=1)
res_freq.head()

# Merging the restaurant dataframe to to_final:
to_final = to_final.merge(res_freq, left_on="Neighborhood", right_on="Neighborhood")
to_final.head()
# Out:
#                    Neighborhood  +/- Population(%)  Population/sqkm  \
# 0               Agincourt North                 -3             3929
# 1  Agincourt South-Malvern West                  8             3034
# 2                     Alderwood                  1             2435
# 3                         Annex                  4            10863
# 4             Banbury-Don Mills                  2             2775
#
#    Average income ($}  French speaking (%)   Latitude  Longitude  \
# 0               30414             4.293615  43.808038 -79.266439
# 1               31825             4.482889  43.781969 -79.257689
# 2               47709             7.383441  43.601717 -79.545232
# 3              112766            19.737273  43.670338 -79.407117
# 4               67757            10.525366  43.752683 -79.365270
#
#    Total crime rate  French Restaurant  Restaurant Total freq
# 0             735.2                  0                      8
# 1            1384.8                  0                     17
# 2             730.1                  0                      1
# 3            1975.5                  2                     35
# 4             798.1                  0                      5

# %% [markdown]
# ####Exporting to .csv (using Colab) since the dataframe contains Foursquare data, of which the API comes with a cap for no of calls

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
to_final.to_csv('to_final.csv')
# !cp to_final.csv "drive/My Drive/"
drive.flush_and_unmount()

# %% [markdown]
# ####Importing again

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9615fdb3-986c-44f0-854f-beb5c5c83ec2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9615fdb3-986c-44f0-854f-beb5c5c83ec2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving to_final.csv to to_final.csv

# %%
to_final = pd.read_csv(io.BytesIO(uploaded['to_final.csv']), thousands=',')
del to_final["Unnamed: 0"]
to_final.head()
# Out:
#                    Neighborhood  +/- Population(%)  Population/sqkm  \
# 0               Agincourt North                 -3             3929
# 1  Agincourt South-Malvern West                  8             3034
# 2                     Alderwood                  1             2435
# 3                         Annex                  4            10863
# 4             Banbury-Don Mills                  2             2775
#
#    Average income ($}  French speaking (%)   Latitude  Longitude  \
# 0               30414             4.293615  43.808038 -79.266439
# 1               31825             4.482889  43.781969 -79.257689
# 2               47709             7.383441  43.601717 -79.545232
# 3              112766            19.737273  43.670338 -79.407117
# 4               67757            10.525366  43.752683 -79.365270
#
#    Total crime rate  French Restaurant  Restaurant Total freq
# 0             735.2                  0                      8
# 1            1384.8                  0                     17
# 2             730.1                  0                      1
# 3            1975.5                  2                     35
# 4             798.1                  0                      5

# %% [markdown]
# ###4. Scoring neighborhoods

# %% [markdown]
# ####I will start by scoring each neighborhood on provided variables
# Since a high crime rate is bad for business, I am inverting the crime rate, such that a lower crime rate will yield a higher score

# %%
to_final["Crime rate inv"]=1/to_final["Total crime rate"]
to_final.head()
# Out:
#                    Neighborhood  +/- Population(%)  Population/sqkm  \
# 0               Agincourt North                 -3             3929
# 1  Agincourt South-Malvern West                  8             3034
# 2                     Alderwood                  1             2435
# 3                         Annex                  4            10863
# 4             Banbury-Don Mills                  2             2775
#
#    Average income ($}  French speaking (%)   Latitude  Longitude  \
# 0               30414             4.293615  43.808038 -79.266439
# 1               31825             4.482889  43.781969 -79.257689
# 2               47709             7.383441  43.601717 -79.545232
# 3              112766            19.737273  43.670338 -79.407117
# 4               67757            10.525366  43.752683 -79.365270
#
#    Total crime rate  French Restaurant  Restaurant Total freq  Crime rate inv
# 0             735.2                  0                      8        0.001360
# 1            1384.8                  0                     17        0.000722
# 2             730.1                  0                      1        0.001370
# 3            1975.5                  2                     35        0.000506
# 4             798.1                  0                      5        0.001253

# %% [markdown]
# ####Variables are converted to a numpy array and normalized

# %%
to_array = to_final[["+/- Population(%)", "Population/sqkm", "Average income ($}",	"French speaking (%)", "French Restaurant", "Restaurant Total freq", "Crime rate inv"]].values.astype(float)
to_array = preprocessing.StandardScaler().fit(to_array).transform(to_array.astype(float))
to_array[0:5]
# Out:
# array([[-0.78354825, -0.4835405 , -0.64338074, -1.10532853, -0.37815145,
#         -0.32369923,  1.339337  ],
#        [ 0.47470441, -0.66910807, -0.60682633, -1.06533826, -0.37815145,
#          0.58467722, -0.47561978],
#        [-0.32600183, -0.79330357, -0.19532368, -0.45250482, -0.37815145,
#         -1.03021424,  1.36636383],
#        [ 0.01715799,  0.95414163,  1.49009107,  2.15763336,  2.73603693,
#          2.40143013, -1.08982812],
#        [-0.21161522, -0.72280863,  0.32405464,  0.2113262 , -0.37815145,
#         -0.62649138,  1.03440664]])

# %% [markdown]
# ####Then converted back to a dataframe "to_norm"

# %%
to_norm = pd.DataFrame(to_array, columns = ["+/- Population(%)", 
                                            "Population/sqkm", 
                                            "Average income ($}",	
                                            "French speaking (%)", 
                                            "French Restaurant", 
                                            "Restaurant Total freq", 
                                            "Crime rate inv"])
neigh=to_final["Neighborhood"]
to_norm.insert(0, "Neighborhood", neigh)
to_norm.head()
# Out:
#                    Neighborhood  +/- Population(%)  Population/sqkm  \
# 0               Agincourt North          -0.783548        -0.483541
# 1  Agincourt South-Malvern West           0.474704        -0.669108
# 2                     Alderwood          -0.326002        -0.793304
# 3                         Annex           0.017158         0.954142
# 4             Banbury-Don Mills          -0.211615        -0.722809
#
#    Average income ($}  French speaking (%)  French Restaurant  \
# 0           -0.643381            -1.105329          -0.378151
# 1           -0.606826            -1.065338          -0.378151
# 2           -0.195324            -0.452505          -0.378151
# 3            1.490091             2.157633           2.736037
# 4            0.324055             0.211326          -0.378151
#
#    Restaurant Total freq  Crime rate inv
# 0              -0.323699        1.339337
# 1               0.584677       -0.475620
# 2              -1.030214        1.366364
# 3               2.401430       -1.089828
# 4              -0.626491        1.034407

# %% [markdown]
# ####Now we calculate the score as the sum of all variables per neighborhood and put it as a column in the to_final dataframe:

# %%
score = np.mean(to_norm, axis=1)
to_final.loc[:,'Score'] = score
del to_final["Crime rate inv"]

# %% [markdown]
# ###

# %%
kclusters = [i for i in range(1,10)]

# %%
#Elbow method
# function returns WSS score for k values from 1 to kmax
def calculate_WSS(points, kmax):
  sse = []
  for k in range(1, kmax+1):
    kmeans = KMeans(n_clusters = k).fit(points)
    centroids = kmeans.cluster_centers_
    pred_clusters = kmeans.predict(points)
    curr_sse = 0
    
    # calculate square of Euclidean distance of each point from its cluster center and add to current WSS
    for i in range(len(points)):
      curr_center = centroids[pred_clusters[i]]
      curr_sse += (points[i, 0] - curr_center[0]) ** 2 + (points[i, 1] - curr_center[1]) ** 2
      
    sse.append(curr_sse)
  return sse

# %%
elbow=calculate_WSS(to_array, 9)

# %%
plt.plot(kclusters,elbow)
plt.xlabel("Kclusters")
plt.ylabel("WSS")
# Out:
# Text(0, 0.5, 'WSS')

# %% [markdown]
# The choice of k here is ambigious and no elbow is seen. Let's try the silhouette method instead:

# %%
#Silhouhette method
from sklearn.metrics import silhouette_score

sil = []
kmax = 10

# dissimilarity would not be defined for a single cluster, thus, minimum number of clusters should be 2
for k in range(2, kmax+1):
  kmeans = KMeans(n_clusters = k).fit(to_array)
  labels = kmeans.labels_
  sil.append(silhouette_score(to_array, labels, metric = 'euclidean'))

# %%
plt.plot(kclusters,sil)
plt.xlabel("Kclusters")
plt.ylabel("Silhouette score")
# Out:
# Text(0, 0.5, 'Silhouette score')

# %% [markdown]
# The silhouette score peaks at k=2 but is fairly similar for k=2-3. The WSS is lower for k=3 so let's go for 3 clusters

# %% [markdown]
# Now we can run the k-means clustering and add a column containing respective cluster to the dataset

# %%
kclusters = 3
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(to_array)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]

to_final.insert(11, 'Cluster Labels', kmeans.labels_)

to_final.head()
# Out:
#                    Neighborhood  +/- Population(%)  Population/sqkm  \
# 0               Agincourt North                 -3             3929
# 1  Agincourt South-Malvern West                  8             3034
# 2                     Alderwood                  1             2435
# 3                         Annex                  4            10863
# 4             Banbury-Don Mills                  2             2775
#
#    Average income ($}  French speaking (%)   Latitude  Longitude  \
# 0               30414             4.293615  43.808038 -79.266439
# 1               31825             4.482889  43.781969 -79.257689
# 2               47709             7.383441  43.601717 -79.545232
# 3              112766            19.737273  43.670338 -79.407117
# 4               67757            10.525366  43.752683 -79.365270
#
#    Total crime rate  French Restaurant  Restaurant Total freq     Score  \
# 0             735.2                  0                      8 -0.339759
# 1            1384.8                  0                     17 -0.305095
# 2             730.1                  0                      1 -0.258448
# 3            1975.5                  2                     35  1.238095
# 4             798.1                  0                      5 -0.052754
#
#    Cluster Labels
# 0               0
# 1               0
# 2               0
# 3               1
# 4               0

# %%
#Lets final round the score to two decimals:
to_final["Score"]=to_final["Score"].round(2)

# %% [markdown]
# ##*Results*

# %% [markdown]
# ####Let's have a look at the characteristics of the top 10 scoring neighborhoods:

# %%
to_final.sort_values(by=['Score'], ascending=False).head(10)
# Out:
#                           Neighborhood  +/- Population(%)  Population/sqkm  \
# 71                     Little Portugal                 29            12859
# 23               Church-Yonge Corridor                 10            23044
# 21                           Casa Loma                  4             5683
# 3                                Annex                  4            10863
# 87                             Niagara                 46            10156
# 137                     Yonge-St.Clair                  7            10708
# 89                North St. James Town                  4            44321
# 116                        The Beaches                  2             6058
# 88                     North Riverdale                 -2             6770
# 16   Bridle Path-Sunnybrook-York Mills                  6             1040
#
#      Average income ($}  French speaking (%)   Latitude  Longitude  \
# 71                45737            13.111382  43.647413 -79.431116
# 23                53583            15.236120  43.670786 -79.385687
# 21               165047            19.556893  43.678102 -79.409416
# 3                112766            19.737273  43.670338 -79.407117
# 87                70623            14.288005  43.644075 -79.408698
# 137              114174            18.518519  43.688078 -79.394396
# 89                32648             9.481601  43.669403 -79.372704
# 116               92580            16.900821  43.671024 -79.296712
# 88                73253            19.091977  43.665470 -79.352594
# 16               308010            19.102094  43.735900 -79.371900
#
#      Total crime rate  French Restaurant  Restaurant Total freq  Score  \
# 71             1144.0                  3                     36   1.64
# 23             4534.1                  3                     28   1.35
# 21              911.7                  2                     17   1.25
# 3              1975.5                  2                     35   1.24
# 87             1581.1                  1                     21   1.21
# 137             646.5                  1                     17   1.19
# 89             1993.0                  0                     24   1.02
# 116             848.5                  2                     16   0.90
# 88             1418.3                  2                     29   0.85
# 16             1316.7                  0                      1   0.85
#
#      Cluster Labels
# 71                1
# 23                1
# 21                2
# 3                 1
# 87                1
# 137               2
# 89                1
# 116               2
# 88                1
# 16                2

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster, scores in zip(to_final['Latitude'], to_final['Longitude'], to_final['Neighborhood'], to_final['Cluster Labels'], to_final["Score"]):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster) + " Score " + str(scores), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_8d47892908f64b6d938c8e48832b3690%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_8d47892908f64b6d938c8e48832b3690%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_8d47892908f64b6d938c8e48832b3690%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_8d47892908f64b6d938c8e48832b3690%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_05b618199cec46f2acdb712f9f4814d3%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20% ...

# %%
to_cluster_score = to_final.groupby("Cluster Labels")["Score"].mean()
to_cluster_sem = to_final.groupby("Cluster Labels")["Score"].sem()
Cluster=["0","1","2"]

plt.bar(Cluster, to_cluster_score)
plt.xlabel("Cluster")
plt.ylabel("Score")
plt.errorbar(Cluster,to_cluster_score, yerr=to_cluster_sem, c="r", ls='none')
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ###Clusters 1 and 2 have the highest scores. Of note, almost all of these neighborhoods are located centrally.

# %% [markdown]
# ####Which are the 10 best/worst neighborhoods for a French restaurant?

# %%
to_french=to_final[["Neighborhood", "Score"]]
to_french.sort_values(by='Score', inplace=True)
to_top=to_french.head(10).tail(10)
to_bottom=to_french.tail(10)
to_french=pd.concat([to_top, to_bottom])
x=to_french["Neighborhood"]
y=to_french["Score"]

plt.figure(figsize=(15, 10))
plt.barh(x,y)
plt.xlabel("Score", fontsize=14)
plt.ylabel("Neighborhood", fontsize=14)
plt.title("Toronto neighborhoods for a French Restaurant start-up: 10 best and worst", fontsize=16)
#plt.show()
plt.savefig('topbottom10.pdf')
files.download('topbottom10.pdf')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
to_french=to_final[["Neighborhood", "Score","Total crime rate"]]
to_french.sort_values(by='Score', ascending=False, inplace=True)
to_top=to_french.head(10)
x=to_top["Neighborhood"]
y=to_top["Total crime rate"]

plt.figure(figsize=(15, 10))
plt.barh(x,y)
plt.xlabel("Total crime rate", fontsize=14)
plt.ylabel("Neighborhood", fontsize=14)
plt.title("Toronto neighborhoods for a French Restaurant start-up: 10 best and worst", fontsize=16)
#plt.show()
plt.savefig('topbottom10.pdf')
files.download('topbottom10.pdf')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ####The location of the 10 best neighborhoods can be visualized using Folium:

# %%
to_top10=to_final.sort_values(by=['Score'], ascending=False).head(10)

map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

for lat, lng, neighborhood in zip(to_top10['Latitude'], to_top10['Longitude'], to_top10['Neighborhood']):
    label = '{}'.format(neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_251c74f4319f436dac51bf1b98983ccf%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_251c74f4319f436dac51bf1b98983ccf%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_251c74f4319f436dac51bf1b98983ccf%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_251c74f4319f436dac51bf1b98983ccf%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_27d4b01eec064d08a42e80d69b899136%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20% ...

# %% [markdown]
# ###Let's check our variables
# ####What does the distribution of French-speakers look like in Toronto?

# %%
to_french=to_final[["Neighborhood", "French speaking (%)"]]
to_french.sort_values(by='French speaking (%)', ascending=False, inplace=True)

x=to_french["Neighborhood"]
y=to_french["French speaking (%)"]
plt.figure(figsize=(24, 6))
plt.bar(x,y)
plt.xlabel("Neighborhood", fontsize=12)
plt.ylabel("French speaking (%)", fontsize=12)
plt.title("French speakers in Toronto", fontsize=16)
plt.xticks(rotation=90, fontsize=8)
plt.show()

#plt.savefig('french.pdf')
#files.download('french.pdf')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-5f9b3359d997> in <module>()
#       4 x=to_french["Neighborhood"]
#       5 y=to_french["French speaking (%)"]
# ----> 6 x, y, rep = zip(to_french.sort_values(by='French speaking (%)', ascending=False, inplace=True))
#       7 plt.figure(figsize=(24, 6))
#       8 bars=plt.bar(x,y)
#
# TypeError: zip argument #1 must support iteration

# %% [markdown]
# ####So French speaking percentage ranges from roughly 3 to 20 % in the neighborhoods. Is French speaking rate correlated with other variables in our dataset, like income?

# %%
R_square = r2_score(to_norm["French speaking (%)"], to_norm["Average income ($}"])

plt.scatter(to_final["French speaking (%)"], to_final["Average income ($}"])
plt.xlabel("French speaking (%)")
plt.ylabel("Average income ($}")
plt.title("French speaking neighborhoods are wealthy")
m, b = np.polyfit(to_final["French speaking (%)"], to_final["Average income ($}"], 1)
plt.plot(to_final["French speaking (%)"], m*to_final["French speaking (%)"]+b, c = "r")
#plt.annotate("r-squared = {:.2f}".format(r2_score(to_norm["French speaking (%)"], to_norm["Average income ($}"]), (3,300000)))
plt.annotate("r-squared = {:.2f}".format(R_square), (3,300000))
#plt.show()
plt.savefig('wealth.pdf')
files.download('wealth.pdf')

# %% [markdown]
# There is a correlation between French speaking neighborhoods and income, although the r2-score is not very high. Simple linear regression is probably not optimal here, I  leave it to the reader to explore it further if interested. It is a good thing that choosen variables correlate as they would synergistically improve the final score.

# %% [markdown]
# ####How about crime rate?

# %%
to_french=to_final[["French speaking (%)", "Total crime rate"]]
to_french.sort_values(by='Total crime rate', inplace=True)

x=to_french["French speaking (%)"]
y=to_french["Total crime rate"]

plt.figure(figsize=(24, 6))
plt.scatter(x,y)
plt.xlabel("French speaking (%)", fontsize=12)
plt.ylabel("Total crime rate", fontsize=12)
plt.title("Crime rate in Toronto", fontsize=16)
plt.xticks(rotation=90, fontsize=8)
plt.show()
#plt.savefig('crime.pdf')
#files.download('crime.pdf')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# Four neighborhoods have a clearly higher crime rate than the rest.

# %% [markdown]
# ####Let's finally have a look at which variables are most influential for the score

# %%
to_norm["Normalized crime rate"]=to_norm["Crime rate inv"]*-1
y = to_final["Score"]
#Calculating R2-scores
R1 = r2_score(to_norm["+/- Population(%)"], y)
R2 = r2_score(to_norm["Population/sqkm"], y)
R3 = r2_score(to_norm["Average income ($}"], y)
R4 = r2_score(to_norm["French speaking (%)"], y)
R5 = r2_score(to_norm["Normalized crime rate"], y)
R6 = r2_score(to_norm["Restaurant Total freq"], y)

#Subplotting
f = plt.figure(figsize=(15,10))
ax = f.add_subplot(231)
ax2 = f.add_subplot(232)
ax3 = f.add_subplot(233)
ax4 = f.add_subplot(234)
ax5 = f.add_subplot(235)
ax6 = f.add_subplot(236)

ax.scatter(to_final["+/- Population(%)"],y)
ax.set_xlabel("+/- Population(%)", fontsize=12)
ax.set_ylabel("Score", fontsize=12)
m, b = np.polyfit(to_final["+/- Population(%)"], y, 1)
ax.plot(to_final["+/- Population(%)"], m*to_final["+/- Population(%)"]+b, c = "r")
ax.annotate("r-squared = {:.2f}".format(R1), (-8,1.6))

ax2.scatter(to_final["Population/sqkm"],y)
ax2.set_xlabel("Population/sqkm", fontsize=12)
m, b = np.polyfit(to_final["Population/sqkm"], y, 1)
ax2.plot(to_final["Population/sqkm"], m*to_final["Population/sqkm"]+b, c = "r")
ax2.annotate("r-squared = {:.2f}".format(R2), (0,2))

ax3.scatter(to_final["Average income ($}"],y)
ax3.set_xlabel("Average income ($}", fontsize=12)
m, b = np.polyfit(to_final["Average income ($}"], y, 1)
ax3.plot(to_final["Average income ($}"], m*to_final["Average income ($}"]+b, c = "r")
ax3.annotate("r-squared = {:.2f}".format(R3), (20000,1.89))

ax4.scatter(to_final["French speaking (%)"],y)
ax4.set_xlabel("French speaking (%)", fontsize=12)
ax4.set_ylabel("Score", fontsize=12)
m, b = np.polyfit(to_final["French speaking (%)"], y, 1)
ax4.plot(to_final["French speaking (%)"], m*to_final["French speaking (%)"]+b, c = "r")
ax4.annotate("r-squared = {:.2f}".format(R4), (2.5,1.6))

ax5.scatter(to_norm["Normalized crime rate"],y)
ax5.set_xlabel("Normalized crime rate", fontsize=12)
m, b = np.polyfit(to_norm["Normalized crime rate"], y, 1)
ax5.plot(to_norm["Normalized crime rate"], m*to_norm["Normalized crime rate"]+b, c = "r")
ax5.annotate("r-squared = {:.2f}".format(R5), (-3.3,1.6))

ax6.scatter(to_final["Restaurant Total freq"],y)
ax6.set_xlabel("Restaurants", fontsize=12)
m, b = np.polyfit(to_final["Restaurant Total freq"], y, 1)
ax6.plot(to_final["Restaurant Total freq"], m*to_final["Restaurant Total freq"]+b, c = "r")
ax6.annotate("r-squared = {:.2f}".format(R6), (0,1.6))

f.suptitle('Correlation between choosen variables and restaurant score', fontsize=16)
plt.savefig('all.pdf')
files.download('all.pdf')

# %% [markdown]
# This is just a quick test with simple linear regression, some would likely fit better with e.g. polynomial regression. The main take-home message is that neighborhoods with a high proportion of French speakers are excellent candidates for setting up the restaurant. Crime rates are not correlated with the restaurant scoring, but is nevertheless of importance for many who wishes to open a venue and should therefore be taken into account in the final decision.

# %% [markdown]
# ####Finally, let's check the contribution of the no. of French Restaurants/neighborhood to the score. Note, that since there are so few restaurants here, it makes more sense with a barplot:

# %%
a = to_final.groupby(to_final['French Restaurant']).sem()
b = to_final.groupby(to_final['French Restaurant']).mean()
b.reset_index(inplace=True)
b["French Restaurant"]=b["French Restaurant"].astype(str)

plt.bar(b["French Restaurant"], b["Score"])
plt.xlabel("Number of French restaurants", fontsize=14)
plt.ylabel("Score", fontsize=14)
plt.errorbar(b["French Restaurant"],b["Score"], yerr=a["Score"], c="r", ls='none')
plt.savefig('rest.png')
files.download('rest.png')

# %% [markdown]
# The number of French restaurants in a neighborhood is also likely important, but since there are quite few of them it is hard to draw definitive conclusions. In general, nearby restaurants can both raise attractivness of the neighborhood for costumers as well as increases competition, especially if they are in the same category.

# %% [markdown]
# ##*Discussion*
# Little Portugal is the top scorer for a French restaurant start-up. One has to bear in mind, however, that there are already three French restaurant along with several other restaurants in the neighborhood, which makes it more competitive. Conversely, if one is looking for a neighborhood devoid of a French restaurant (least competitive), two placeed in the top 10 list: North St. James Town and Bridle Path-Sunnybrook-York Mills. These are quite dissimilar, North St. James Town (cluster 1) is densely populated, with relatively low average income and above average crime rate; Bridle Path-Sunnybrook-York Mills (cluster 2) has a very high average income and below-average crime rate but is relatively sparsely populated and have only one restaurant. For a highly ambitious restaurant I would in this case recommend Bridle Path-Sunnybrook-York Mills, e.g. according to [Guide Michelin's grading definition](https://guide.michelin.com/th/en/to-the-stars-and-beyond-th), stars are provided based on whether the visit is worth a stay, detour or special journey. Therefore a less dense neighborhood is not a problem if people are willing to travel (although the restaurant might risk running a cold start).
#
# ##*Conclusion*
# To conclude, this analysis has provided putative neighborhoods for a French cusine start-up and can serve as basis for customers to further explore top scoring areas for a good spot to open their business.
